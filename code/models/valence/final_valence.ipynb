# %%
import os
import pandas as pd
import numpy as np
import glob
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, f1_score, accuracy_score, precision_score, recall_score
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'

# Get a list of all feature file paths in the directory
feature_files = glob.glob(directory_path + '/*.csv')

# Read the feature file into a DataFrame
df = pd.read_csv(feature_files[0])

list_of_column_names = list(df.columns.drop(['Arousal_Value', 'Valence_Value', 'frameTime']))

print(list_of_column_names)
print(len(list_of_column_names))

! pip install opensmile
import pandas as pd
import opensmile

# Initialize OpenSMILE
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.Functionals,
)

# Process the audio file
y = smile.process_file('/content/drive/MyDrive/FYP_dataset/CNN_Features/abc.wav')

# Set Pandas options to display more rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Print the extracted features
smile_features= set((y.keys()))
print(smile_features)

set_our_features=set(list_of_column_names)
print(set_our_features)

dont_have_features_set=set_our_features-smile_features
print(dont_have_features_set)

dont_have_features_list=list(dont_have_features_set)
print(len(dont_have_features_list))

smile_features_have_in_the_dataset=set_our_features - dont_have_features_set
print(smile_features_have_in_the_dataset)

smile_features_have_in_the_dataset=list(smile_features_have_in_the_dataset)
print(len(smile_features_have_in_the_dataset))

drop_list=[]
#drop_list=dont_have_features_list
for i in range(0,len(dont_have_features_list)):
  drop_list.append(dont_have_features_list[i])

drop_list.append('Arousal_Value')
drop_list.append('Valence_Value')
drop_list.append('frameTime')

print(drop_list)
print(len(drop_list))

print(len(feature_files))

# Define lists to store the feature and target data
X = []
y_a = []
y_v = []

# Iterate over each feature file
for file in feature_files:
    # Read the feature file into a DataFrame
    df = pd.read_csv(file)

    # Extract the features and target variables
    features = df.drop(drop_list, axis=1).values
    arousal = df['Arousal_Value'].values
    valence = df['Valence_Value'].values

    # Append the data to the lists
    X.append(features)
    y_a.append(arousal)
    y_v.append(valence)

# Concatenate the feature and target arrays
X = np.concatenate(X)
y_a = np.concatenate(y_a)
y_v = np.concatenate(y_v)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape the input data for LSTM
X_reshaped = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

# Define the number of folds for cross-validation
num_folds = 5

# Initialize lists to store evaluation results
mse_v = []
mae_v = []
rmse_v = []
r2_v = []
f1_v = []
accuracy_v = []
precision_v = []
recall_v = []

# Perform tenfold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(X_reshaped):
    X_train, X_val = X_reshaped[train_index], X_reshaped[test_index]
    y_v_train, y_v_val = y_v[train_index], y_v[test_index]

    # Split the validation set further into val and test sets
    val_size = len(X_val) // 2
    X_val, X_test = X_val[:val_size], X_val[val_size:]
    y_v_val, y_v_test = y_v_val[:val_size], y_v_val[val_size:]

    # Build the BiLSTM model for Arousal
    model_v = Sequential()
    model_v.add(Bidirectional(CuDNNLSTM(64, return_sequences=True), input_shape=(X_train.shape[1], 1)))
    model_v.add(Flatten())

    # Add DNN layers with dropout (modify as needed)
    dnn_layers = [512, 256, 128,64,32]  # Modify this list as needed

    for layer_size in dnn_layers:
        model_v.add(Dense(layer_size, activation='relu'))
        # Add dropout if needed: model_a.add(Dropout(dropout_rate))

    model_v.add(Dense(1))
    model_v.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

    # Train the Arousal model
    model_v.fit(X_train, y_v_train, validation_data=(X_val, y_v_val), epochs=25, batch_size=32)

    # Evaluate the model on the test set
    predictions_v = model_v.predict(X_test)

    # Reshape predictions_a to match the shape of y_a_test
    predictions_v = predictions_v.reshape(y_v_test.shape)

    # Calculate additional evaluation metrics
    mse_v.append(mean_squared_error(y_v_test, predictions_v))
    mae_v.append(mean_absolute_error(y_v_test, predictions_v))
    rmse_v.append(np.sqrt(mean_squared_error(y_v_test, predictions_v)))
    r2_v.append(r2_score(y_v_test, predictions_v))

    # Convert regression predictions to binary labels
    threshold = 0
    binary_predictions_v = (predictions_v >= threshold).astype(int)
    y_v_test_binary = (y_v_test >= threshold).astype(int)

    # Calculate F1-score, accuracy, precision, and recall for binary classification
    f1_v.append(f1_score(y_v_test_binary, binary_predictions_v))
    accuracy_v.append(accuracy_score(y_v_test_binary, binary_predictions_v))
    precision_v.append(precision_score(y_v_test_binary, binary_predictions_v))
    recall_v.append(recall_score(y_v_test_binary, binary_predictions_v))

# Calculate average performance across all folds
average_mse_v = np.mean(mse_v)
average_mae_v = np.mean(mae_v)
average_rmse_v = np.mean(rmse_v)
average_r2_v = np.mean(r2_v)
average_f1_v = np.mean(f1_v)
average_accuracy_v = np.mean(accuracy_v)
average_precision_v = np.mean(precision_v)
average_recall_v = np.mean(recall_v)

print(f'Average Arousal MSE: {average_mse_v:.4f}')
print(f'Average Arousal MAE: {average_mae_v:.4f}')
print(f'Average Arousal RMSE: {average_rmse_v:.4f}')
print(f'Average Arousal R2 Score: {average_r2_v:.4f}')
print(f'Average Arousal F1 Score: {average_f1_v:.4f}')
print(f'Average Arousal Accuracy: {average_accuracy_v:.4f}')
print(f'Average Arousal Precision: {average_precision_v:.4f}')
print(f'Average Arousal Recall: {average_recall_v:.4f}')

# Define the directory path to save the model
model_save_path = '/content/drive/MyDrive/FYP_dataset/models'  # Modify as needed

# Save the Arousal model to the specified directory
model_v.save(os.path.join(model_save_path, 'valence_model.h5'))
# Out:
# Mounted at /content/drive
# ['F0final_sma_stddev', 'F0final_sma_amean', 'voicingFinalUnclipped_sma_stddev', 'voicingFinalUnclipped_sma_amean', 'jitterLocal_sma_stddev', 'jitterLocal_sma_amean', 'jitterDDP_sma_stddev', 'jitterDDP_sma_amean', 'shimmerLocal_sma_stddev', 'shimmerLocal_sma_amean', 'logHNR_sma_stddev', 'logHNR_sma_amean', 'audspec_lengthL1norm_sma_stddev', 'audspec_lengthL1norm_sma_amean', 'audspecRasta_lengthL1norm_sma_stddev', 'audspecRasta_lengthL1norm_sma_amean', 'pcm_RMSenergy_sma_stddev', 'pcm_RMSenergy_sma_amean', 'pcm_zcr_sma_stddev', 'pcm_zcr_sma_amean', 'audSpec_Rfilt_sma[0]_stddev', 'audSpec_Rfilt_sma[0]_amean', 'audSpec_Rfilt_sma[1]_stddev', 'audSpec_Rfilt_sma[1]_amean', 'audSpec_Rfilt_sma[2]_stddev', 'audSpec_Rfilt_sma[2]_amean', 'audSpec_Rfilt_sma[3]_stddev', 'audSpec_Rfilt_sma[3]_amean', 'audSpec_Rfilt_sma[4]_stddev', 'audSpec_Rfilt_sma[4]_amean', 'audSpec_Rfilt_sma[5]_stddev', 'audSpec_Rfilt_sma[5]_amean', 'audSpec_Rfilt_sma[6]_stddev', 'audSpec_Rfilt_sma[6]_amean', 'audSpec_Rfilt_sma[7]_stddev', 'audSpec_Rfilt_sma[7]_amean', 'audSpec_Rfilt_sma[8]_stddev', 'audSpec_Rfilt_sma[8]_amean', 'audSpec_Rfilt_sma[9]_stddev', 'audSpec_Rfilt_sma[9]_amean', 'audSpec_Rfilt_sma[10]_stddev', 'audSpec_Rfilt_sma[10]_amean', 'audSpec_Rfilt_sma[11]_stddev', 'audSpec_Rfilt_sma[11]_amean', 'audSpec_Rfilt_sma[12]_stddev', 'audSpec_Rfilt_sma[12]_amean', 'audSpec_Rfilt_sma[13]_stddev', 'audSpec_Rfilt_sma[13]_amean', 'audSpec_Rfilt_sma[14]_stddev', 'audSpec_Rfilt_sma[14]_amean', 'audSpec_Rfilt_sma[15]_stddev', 'audSpec_Rfilt_sma[15]_amean', 'audSpec_Rfilt_sma[16]_stddev', 'audSpec_Rfilt_sma[16]_amean', 'audSpec_Rfilt_sma[17]_stddev', 'audSpec_Rfilt_sma[17]_amean', 'audSpec_Rfilt_sma[18]_stddev', 'audSpec_Rfilt_sma[18]_amean', 'audSpec_Rfilt_sma[19]_stddev', 'audSpec_Rfilt_sma[19]_amean', 'audSpec_Rfilt_sma[20]_stddev', 'audSpec_Rfilt_sma[20]_amean', 'audSpec_Rfilt_sma[21]_stddev', 'audSpec_Rfilt_sma[21]_amean', 'audSpec_Rfilt_sma[22]_stddev', 'audSpec_Rfilt_sma[22]_amean', 'audSpec_Rfilt_sma[23]_stddev', 'audSpec_Rfilt_sma[23]_amean', 'audSpec_Rfilt_sma[24]_stddev', 'audSpec_Rfilt_sma[24]_amean', 'audSpec_Rfilt_sma[25]_stddev', 'audSpec_Rfilt_sma[25]_amean', 'pcm_fftMag_fband250-650_sma_stddev', 'pcm_fftMag_fband250-650_sma_amean', 'pcm_fftMag_fband1000-4000_sma_stddev', 'pcm_fftMag_fband1000-4000_sma_amean', 'pcm_fftMag_spectralRollOff25.0_sma_stddev', 'pcm_fftMag_spectralRollOff25.0_sma_amean', 'pcm_fftMag_spectralRollOff50.0_sma_stddev', 'pcm_fftMag_spectralRollOff50.0_sma_amean', 'pcm_fftMag_spectralRollOff75.0_sma_stddev', 'pcm_fftMag_spectralRollOff75.0_sma_amean', 'pcm_fftMag_spectralRollOff90.0_sma_stddev', 'pcm_fftMag_spectralRollOff90.0_sma_amean', 'pcm_fftMag_spectralFlux_sma_stddev', 'pcm_fftMag_spectralFlux_sma_amean', 'pcm_fftMag_spectralCentroid_sma_stddev', 'pcm_fftMag_spectralCentroid_sma_amean', 'pcm_fftMag_spectralEntropy_sma_stddev', 'pcm_fftMag_spectralEntropy_sma_amean', 'pcm_fftMag_spectralVariance_sma_stddev', 'pcm_fftMag_spectralVariance_sma_amean', 'pcm_fftMag_spectralSkewness_sma_stddev', 'pcm_fftMag_spectralSkewness_sma_amean', 'pcm_fftMag_spectralKurtosis_sma_stddev', 'pcm_fftMag_spectralKurtosis_sma_amean', 'pcm_fftMag_spectralSlope_sma_stddev', 'pcm_fftMag_spectralSlope_sma_amean', 'pcm_fftMag_psySharpness_sma_stddev', 'pcm_fftMag_psySharpness_sma_amean', 'pcm_fftMag_spectralHarmonicity_sma_stddev', 'pcm_fftMag_spectralHarmonicity_sma_amean', 'pcm_fftMag_mfcc_sma[1]_stddev', 'pcm_fftMag_mfcc_sma[1]_amean', 'pcm_fftMag_mfcc_sma[2]_stddev', 'pcm_fftMag_mfcc_sma[2]_amean', 'pcm_fftMag_mfcc_sma[3]_stddev', 'pcm_fftMag_mfcc_sma[3]_amean', 'pcm_fftMag_mfcc_sma[4]_stddev', 'pcm_fftMag_mfcc_sma[4]_amean', 'pcm_fftMag_mfcc_sma[5]_stddev', 'pcm_fftMag_mfcc_sma[5]_amean', 'pcm_fftMag_mfcc_sma[6]_stddev', 'pcm_fftMag_mfcc_sma[6]_amean', 'pcm_fftMag_mfcc_sma[7]_stddev', 'pcm_fftMag_mfcc_sma[7]_amean', 'pcm_fftMag_mfcc_sma[8]_stddev', 'pcm_fftMag_mfcc_sma[8]_amean', 'pcm_fftMag_mfcc_sma[9]_stddev', 'pcm_fftMag_mfcc_sma[9]_amean', 'pcm_ ...
# 260
# Collecting opensmile
#   Downloading opensmile-2.4.2-py3-none-any.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 41.8 MB/s eta 0:00:00
# Collecting audobject>=0.6.1 (from opensmile)
#   Downloading audobject-0.7.9-py3-none-any.whl (24 kB)
# Collecting audinterface>=0.7.0 (from opensmile)
#   Downloading audinterface-1.1.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 8.5 MB/s eta 0:00:00
# Collecting audformat<2.0.0,>=1.0.1 (from audinterface>=0.7.0->opensmile)
#   Downloading audformat-1.0.1-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 9.3 MB/s eta 0:00:00
# Collecting audiofile>=1.3.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audiofile-1.3.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.7 MB/s eta 0:00:00
# Collecting audmath>=1.3.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audmath-1.3.0-py3-none-any.whl (22 kB)
# Collecting audresample<2.0.0,>=1.1.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audresample-1.3.2-py3-none-manylinux_2_17_x86_64.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 20.1 MB/s eta 0:00:00
# Collecting audeer>=1.18.0 (from audobject>=0.6.1->opensmile)
#   Downloading audeer-1.20.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from audobject>=0.6.1->opensmile) (6.8.0)
# Collecting oyaml (from audobject>=0.6.1->opensmile)
#   Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from audeer>=1.18.0->audobject>=0.6.1->opensmile) (4.66.1)
# Collecting iso-639 (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.4/167.4 kB 23.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iso3166 (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (6.0.1)
# Requirement already satisfied: pandas>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.23.5)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (0.12.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile) (3.16.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2023.3.post1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (1.16.0)
# Building wheels for collected packages: iso-639
#   Building wheel for iso-639 (setup.py) ... done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=168842 sha256=4ab8c94bf8d37a9fcfd988709f11ff2924abfa26a392f7cc8ee1705911e0882b
#   Stored in directory: /root/.cache/pip/wheels/d8/78/cc/5478ca3b1c3f602eae6f8cdbd78f909c0a0bfa0bbcb5c7771f
# Successfully built iso-639
# Installing collected packages: iso-639, oyaml, iso3166, audresample, audmath, audeer, audobject, audiofile, audformat, audinterface, opensmile
# Successfully installed audeer-1.20.1 audformat-1.0.1 audinterface-1.1.0 audiofile-1.3.0 audmath-1.3.0 audobject-0.7.9 audresample-1.3.2 iso-639-0.4.5 iso3166-2.1.1 opensmile-2.4.2 oyaml-1.0
# {'F0final_sma_de_upleveltime25', 'mfcc_sma[8]_qregerrQ', 'mfcc_sma_de[10]_upleveltime25', 'audSpec_Rfilt_sma[9]_stddevRisingSlope', 'audSpec_Rfilt_sma[0]_lpc1', 'mfcc_sma[1]_percentile99.0', 'audSpec_Rfilt_sma[20]_meanRisingSlope', 'audspecRasta_lengthL1norm_sma_minRangeRel', 'pcm_fftMag_spectralRollOff90.0_sma_de_peakMeanRel', 'audspecRasta_lengthL1norm_sma_stddev', 'audSpec_Rfilt_sma_de[15]_lpc4', 'audSpec_Rfilt_sma_de[1]_percentile99.0', 'audSpec_Rfilt_sma[8]_quartile3', 'audSpec_Rfilt_sma[24]_minSegLen', 'jitterDDP_sma_de_quartile2', 'audSpec_Rfilt_sma[23]_quartile2', 'pcm_fftMag_spectralRollOff90.0_sma_de_iqr1-2', 'pcm_fftMag_spectralRollOff90.0_sma_de_maxSegLen', 'mfcc_sma_de[2]_peakRangeRel', 'audSpec_Rfilt_sma[17]_minRangeRel', 'pcm_fftMag_spectralCentroid_sma_de_skewness', 'mfcc_sma[10]_meanPeakDist', 'pcm_fftMag_fband1000-4000_sma_stddev', 'audSpec_Rfilt_sma[8]_risetime', 'pcm_fftMag_spectralFlux_sma_de_meanSegLen', 'pcm_fftMag_spectralFlux_sma_amean', 'mfcc_sma[1]_minSegLen', 'pcm_fftMag_spectralCentroid_sma_lpc3', 'audSpec_Rfilt_sma[2]_peakRangeAbs', 'mfcc_sma[4]_minSegLen', 'mfcc_sma[6]_lpc2', 'audSpec_Rfilt_sma_de[13]_peakMeanRel', 'mfcc_sma[14]_kurtosis', 'mfcc_sma_de[13]_peakMeanAbs', 'mfcc_sma_de[8]_rqmean', 'audSpec_Rfilt_sma_de[17]_minPos', 'mfcc_sma_de[4]_meanFallingSlope', 'pcm_fftMag_spectralFlux_sma_de_peakMeanMeanDist', 'pcm_fftMag_spectralRollOff25.0_sma_de_upleveltime75', 'pcm_fftMag_fband1000-4000_sma_meanPeakDist', 'jitterDDP_sma_pctlrange0-1', 'pcm_fftMag_spectralSlope_sma_de_kurtosis', 'audSpec_Rfilt_sma_de[24]_peakMeanMeanDist', 'audSpec_Rfilt_sma[25]_kurtosis', 'pcm_fftMag_fband250-650_sma_lpc2', 'mfcc_sma[6]_kurtosis', 'audSpec_Rfilt_sma_de[4]_iqr2-3', 'audSpec_Rfilt_sma_de[18]_stddevRisingSlope', 'voicingFinalUnclipped_sma_lpc3', 'mfcc_sma[6]_peakMeanMeanDist', 'audSpec_Rfilt_sma_de[17]_quartile3', 'audSpec_Rfilt_sma[1]_upleveltime75', 'mfcc_sma_de[4]_maxSegLen', 'audSpec_Rfilt_sma[12]_pctlrange0-1', 'pcm_fftMag_fband250-650_sma_meanFallingSlope', 'audspecRasta_lengthL1norm_sma_de_peakMeanMeanDist', 'pcm_fftMag_spectralSlope_sma_lpc1', 'pcm_fftMag_spectralRollOff75.0_sma_de_risetime', 'pcm_fftMag_psySharpness_sma_upleveltime90', 'pcm_fftMag_psySharpness_sma_quartile1', 'audSpec_Rfilt_sma_de[0]_meanPeakDist', 'mfcc_sma_de[13]_lpc1', 'pcm_fftMag_spectralVariance_sma_de_rqmean', 'pcm_fftMag_spectralHarmonicity_sma_de_flatness', 'audSpec_Rfilt_sma[12]_peakMeanRel', 'audSpec_Rfilt_sma_de[6]_lpc3', 'audSpec_Rfilt_sma_de[19]_peakMeanAbs', 'audSpec_Rfilt_sma[18]_skewness', 'mfcc_sma_de[11]_meanSegLen', 'audSpec_Rfilt_sma_de[24]_stddevFallingSlope', 'audSpec_Rfilt_sma[21]_centroid', 'audSpec_Rfilt_sma_de[7]_percentile1.0', 'pcm_fftMag_spectralRollOff75.0_sma_de_posamean', 'mfcc_sma_de[6]_upleveltime50', 'pcm_fftMag_spectralRollOff25.0_sma_centroid', 'audspec_lengthL1norm_sma_de_peakRangeRel', 'audSpec_Rfilt_sma[18]_lpc4', 'mfcc_sma[2]_kurtosis', 'audSpec_Rfilt_sma[22]_lpc4', 'audSpec_Rfilt_sma[16]_lpc0', 'mfcc_sma[9]_linregc2', 'audSpec_Rfilt_sma_de[13]_meanRisingSlope', 'audSpec_Rfilt_sma_de[0]_lpc3', 'mfcc_sma[6]_meanSegLen', 'mfcc_sma_de[3]_segLenStddev', 'audSpec_Rfilt_sma[14]_peakRangeAbs', 'jitterLocal_sma_de_risetime', 'audSpec_Rfilt_sma[19]_maxPos', 'mfcc_sma[11]_pctlrange0-1', 'audSpec_Rfilt_sma[0]_amean', 'pcm_fftMag_spectralEntropy_sma_lpgain', 'audSpec_Rfilt_sma[6]_flatness', 'audSpec_Rfilt_sma[11]_range', 'audSpec_Rfilt_sma_de[17]_pctlrange0-1', 'audSpec_Rfilt_sma[7]_maxSegLen', 'jitterLocal_sma_maxPos', 'pcm_fftMag_spectralRollOff75.0_sma_minSegLen', 'pcm_fftMag_spectralSlope_sma_de_percentile99.0', 'pcm_fftMag_spectralVariance_sma_minPos', 'audSpec_Rfilt_sma_de[1]_meanFallingSlope', 'pcm_fftMag_spectralCentroid_sma_de_kurtosis', 'audSpec_Rfilt_sma[8]_quartile2', 'pcm_fftMag_spectralRollOff50.0_sma_qregc3', 'audSpec_Rfilt_sma[19]_upleveltime75', 'mfcc_sma[13]_maxPos', 'audSpec_Rfilt_sma_de[12]_quartile1', 'pcm_fftMag_spectralSkewness_sma_meanFallingSlope', 'audSpec_Rfilt_sma_de[22]_peakMe ...
# {'pcm_fftMag_mfcc_sma_de[4]_amean', 'audSpec_Rfilt_sma_de[25]_amean', 'audSpec_Rfilt_sma[0]_amean', 'audspec_lengthL1norm_sma_de_stddev', 'audSpec_Rfilt_sma[18]_amean', 'pcm_fftMag_mfcc_sma_de[13]_amean', 'audSpec_Rfilt_sma[4]_stddev', 'audSpec_Rfilt_sma[5]_amean', 'pcm_fftMag_spectralRollOff25.0_sma_amean', 'audSpec_Rfilt_sma_de[0]_amean', 'shimmerLocal_sma_de_amean', 'pcm_fftMag_mfcc_sma_de[5]_stddev', 'audSpec_Rfilt_sma[2]_stddev', 'audSpec_Rfilt_sma_de[2]_stddev', 'audSpec_Rfilt_sma_de[23]_stddev', 'audSpec_Rfilt_sma[0]_stddev', 'pcm_fftMag_spectralRollOff90.0_sma_de_amean', 'pcm_fftMag_mfcc_sma[11]_stddev', 'audspecRasta_lengthL1norm_sma_stddev', 'audSpec_Rfilt_sma[3]_amean', 'audSpec_Rfilt_sma[21]_amean', 'audSpec_Rfilt_sma[11]_stddev', 'F0final_sma_amean', 'audSpec_Rfilt_sma_de[18]_stddev', 'audSpec_Rfilt_sma_de[2]_amean', 'pcm_fftMag_spectralSkewness_sma_de_stddev', 'pcm_fftMag_mfcc_sma[4]_stddev', 'audSpec_Rfilt_sma[10]_amean', 'audSpec_Rfilt_sma[7]_amean', 'voicingFinalUnclipped_sma_de_stddev', 'pcm_fftMag_mfcc_sma_de[8]_amean', 'pcm_fftMag_mfcc_sma_de[7]_amean', 'pcm_fftMag_mfcc_sma_de[9]_stddev', 'pcm_fftMag_spectralVariance_sma_de_amean', 'pcm_RMSenergy_sma_amean', 'voicingFinalUnclipped_sma_amean', 'audSpec_Rfilt_sma_de[4]_amean', 'audSpec_Rfilt_sma_de[24]_stddev', 'jitterLocal_sma_amean', 'pcm_fftMag_spectralSlope_sma_stddev', 'pcm_fftMag_spectralRollOff75.0_sma_amean', 'audSpec_Rfilt_sma_de[8]_stddev', 'audSpec_Rfilt_sma[24]_stddev', 'audSpec_Rfilt_sma_de[22]_stddev', 'audSpec_Rfilt_sma[12]_stddev', 'pcm_fftMag_spectralVariance_sma_stddev', 'audSpec_Rfilt_sma[10]_stddev', 'shimmerLocal_sma_de_stddev', 'pcm_fftMag_mfcc_sma[5]_stddev', 'pcm_fftMag_mfcc_sma[7]_amean', 'pcm_fftMag_mfcc_sma_de[14]_stddev', 'pcm_fftMag_spectralVariance_sma_de_stddev', 'pcm_fftMag_mfcc_sma[14]_amean', 'audSpec_Rfilt_sma[20]_stddev', 'audspecRasta_lengthL1norm_sma_de_amean', 'pcm_fftMag_spectralRollOff50.0_sma_stddev', 'jitterLocal_sma_de_stddev', 'pcm_fftMag_mfcc_sma_de[2]_amean', 'pcm_fftMag_psySharpness_sma_amean', 'pcm_fftMag_spectralRollOff25.0_sma_stddev', 'audSpec_Rfilt_sma_de[16]_stddev', 'pcm_fftMag_mfcc_sma[7]_stddev', 'audspecRasta_lengthL1norm_sma_amean', 'audSpec_Rfilt_sma[9]_stddev', 'pcm_fftMag_mfcc_sma[12]_stddev', 'audSpec_Rfilt_sma[21]_stddev', 'pcm_fftMag_spectralCentroid_sma_stddev', 'audSpec_Rfilt_sma_de[19]_stddev', 'pcm_RMSenergy_sma_de_amean', 'pcm_fftMag_spectralEntropy_sma_de_amean', 'F0final_sma_stddev', 'F0final_sma_de_stddev', 'pcm_fftMag_mfcc_sma_de[6]_stddev', 'pcm_fftMag_mfcc_sma[14]_stddev', 'jitterDDP_sma_amean', 'pcm_fftMag_spectralHarmonicity_sma_stddev', 'audSpec_Rfilt_sma_de[9]_stddev', 'pcm_fftMag_fband1000-4000_sma_stddev', 'audSpec_Rfilt_sma_de[14]_amean', 'audSpec_Rfilt_sma_de[17]_stddev', 'pcm_fftMag_mfcc_sma_de[10]_amean', 'audSpec_Rfilt_sma_de[13]_stddev', 'pcm_RMSenergy_sma_de_stddev', 'pcm_fftMag_spectralSkewness_sma_stddev', 'pcm_fftMag_spectralRollOff25.0_sma_de_amean', 'shimmerLocal_sma_stddev', 'pcm_fftMag_mfcc_sma[10]_amean', 'pcm_fftMag_spectralFlux_sma_amean', 'pcm_RMSenergy_sma_stddev', 'audSpec_Rfilt_sma[15]_amean', 'pcm_fftMag_mfcc_sma[2]_amean', 'pcm_fftMag_mfcc_sma_de[7]_stddev', 'audSpec_Rfilt_sma[4]_amean', 'pcm_fftMag_spectralSlope_sma_de_stddev', 'pcm_fftMag_mfcc_sma[11]_amean', 'audSpec_Rfilt_sma_de[16]_amean', 'pcm_fftMag_mfcc_sma_de[12]_stddev', 'pcm_fftMag_mfcc_sma[13]_amean', 'audSpec_Rfilt_sma_de[18]_amean', 'audSpec_Rfilt_sma[15]_stddev', 'pcm_fftMag_mfcc_sma[6]_amean', 'pcm_zcr_sma_de_amean', 'pcm_fftMag_mfcc_sma[9]_stddev', 'audSpec_Rfilt_sma[19]_amean', 'pcm_fftMag_spectralRollOff25.0_sma_de_stddev', 'audSpec_Rfilt_sma[9]_amean', 'audSpec_Rfilt_sma[14]_stddev', 'pcm_fftMag_fband250-650_sma_de_stddev', 'audSpec_Rfilt_sma_de[20]_amean', 'pcm_fftMag_mfcc_sma[4]_amean', 'pcm_fftMag_psySharpness_sma_de_amean', 'audSpec_Rfilt_sma_de[22]_amean', 'audSpec_Rfilt_sma_de[20]_stddev', 'audSpec_Rfilt_sma_de[8]_amean', 'audSpec_Rfilt_sma_de[23]_amean', 'pcm_fftMag_mfcc_sma[13]_ ...
# {'pcm_fftMag_mfcc_sma_de[4]_amean', 'audSpec_Rfilt_sma_de[25]_amean', 'pcm_fftMag_mfcc_sma_de[13]_amean', 'audSpec_Rfilt_sma_de[0]_amean', 'pcm_fftMag_spectralRollOff90.0_sma_de_amean', 'pcm_fftMag_mfcc_sma[11]_stddev', 'audSpec_Rfilt_sma_de[2]_amean', 'pcm_fftMag_mfcc_sma[4]_stddev', 'pcm_fftMag_mfcc_sma_de[8]_amean', 'pcm_fftMag_mfcc_sma_de[7]_amean', 'pcm_fftMag_mfcc_sma_de[9]_stddev', 'pcm_fftMag_spectralVariance_sma_de_amean', 'audSpec_Rfilt_sma_de[4]_amean', 'pcm_fftMag_mfcc_sma[5]_stddev', 'pcm_fftMag_mfcc_sma[7]_amean', 'pcm_fftMag_mfcc_sma_de[14]_stddev', 'pcm_fftMag_mfcc_sma[14]_amean', 'audspecRasta_lengthL1norm_sma_de_amean', 'pcm_fftMag_mfcc_sma_de[2]_amean', 'pcm_fftMag_mfcc_sma[7]_stddev', 'pcm_fftMag_mfcc_sma[12]_stddev', 'pcm_RMSenergy_sma_de_amean', 'pcm_fftMag_spectralEntropy_sma_de_amean', 'pcm_fftMag_mfcc_sma_de[6]_stddev', 'pcm_fftMag_mfcc_sma[14]_stddev', 'audSpec_Rfilt_sma_de[14]_amean', 'pcm_fftMag_mfcc_sma_de[10]_amean', 'pcm_fftMag_spectralRollOff25.0_sma_de_amean', 'pcm_fftMag_mfcc_sma[10]_amean', 'pcm_fftMag_mfcc_sma[2]_amean', 'pcm_fftMag_mfcc_sma_de[7]_stddev', 'pcm_fftMag_mfcc_sma[11]_amean', 'audSpec_Rfilt_sma_de[16]_amean', 'pcm_fftMag_mfcc_sma[13]_amean', 'audSpec_Rfilt_sma_de[18]_amean', 'pcm_fftMag_mfcc_sma[6]_amean', 'pcm_zcr_sma_de_amean', 'pcm_fftMag_mfcc_sma[9]_stddev', 'audSpec_Rfilt_sma_de[20]_amean', 'pcm_fftMag_mfcc_sma[4]_amean', 'pcm_fftMag_psySharpness_sma_de_amean', 'audSpec_Rfilt_sma_de[22]_amean', 'audSpec_Rfilt_sma_de[8]_amean', 'audSpec_Rfilt_sma_de[23]_amean', 'pcm_fftMag_mfcc_sma[13]_stddev', 'pcm_fftMag_spectralRollOff50.0_sma_de_amean', 'pcm_fftMag_spectralSkewness_sma_de_amean', 'pcm_fftMag_mfcc_sma[3]_amean', 'audSpec_Rfilt_sma_de[21]_amean', 'pcm_fftMag_mfcc_sma[8]_amean', 'pcm_fftMag_mfcc_sma_de[1]_stddev', 'pcm_fftMag_spectralKurtosis_sma_de_amean', 'audSpec_Rfilt_sma_de[11]_amean', 'audSpec_Rfilt_sma_de[12]_amean', 'audSpec_Rfilt_sma_de[15]_amean', 'audSpec_Rfilt_sma_de[19]_amean', 'pcm_fftMag_mfcc_sma[1]_stddev', 'pcm_fftMag_mfcc_sma_de[6]_amean', 'pcm_fftMag_mfcc_sma_de[8]_stddev', 'pcm_fftMag_mfcc_sma_de[10]_stddev', 'pcm_fftMag_fband250-650_sma_de_amean', 'pcm_fftMag_mfcc_sma[5]_amean', 'pcm_fftMag_mfcc_sma[8]_stddev', 'pcm_fftMag_mfcc_sma_de[9]_amean', 'audSpec_Rfilt_sma_de[3]_amean', 'pcm_fftMag_mfcc_sma[6]_stddev', 'pcm_fftMag_mfcc_sma_de[2]_stddev', 'pcm_fftMag_mfcc_sma_de[3]_stddev', 'audspec_lengthL1norm_sma_de_amean', 'pcm_fftMag_spectralCentroid_sma_de_amean', 'pcm_fftMag_mfcc_sma_de[12]_amean', 'pcm_fftMag_mfcc_sma[3]_stddev', 'pcm_fftMag_mfcc_sma_de[5]_stddev', 'pcm_fftMag_spectralFlux_sma_de_amean', 'audSpec_Rfilt_sma_de[1]_amean', 'audSpec_Rfilt_sma_de[24]_amean', 'pcm_fftMag_mfcc_sma_de[3]_amean', 'audSpec_Rfilt_sma_de[17]_amean', 'pcm_fftMag_mfcc_sma_de[1]_amean', 'pcm_fftMag_mfcc_sma_de[11]_stddev', 'pcm_fftMag_mfcc_sma_de[14]_amean', 'pcm_fftMag_mfcc_sma_de[4]_stddev', 'audSpec_Rfilt_sma_de[7]_amean', 'audSpec_Rfilt_sma_de[6]_amean', 'pcm_fftMag_mfcc_sma[2]_stddev', 'pcm_fftMag_mfcc_sma[12]_amean', 'audSpec_Rfilt_sma_de[5]_amean', 'audSpec_Rfilt_sma_de[9]_amean', 'pcm_fftMag_mfcc_sma[1]_amean', 'pcm_fftMag_mfcc_sma[10]_stddev', 'pcm_fftMag_fband1000-4000_sma_de_amean', 'pcm_fftMag_mfcc_sma_de[5]_amean', 'pcm_fftMag_mfcc_sma_de[11]_amean', 'audSpec_Rfilt_sma_de[13]_amean', 'pcm_fftMag_mfcc_sma[9]_amean', 'pcm_fftMag_spectralHarmonicity_sma_de_amean', 'pcm_fftMag_spectralRollOff75.0_sma_de_amean', 'audSpec_Rfilt_sma_de[10]_amean', 'pcm_fftMag_mfcc_sma_de[13]_stddev', 'pcm_fftMag_mfcc_sma_de[12]_stddev', 'pcm_fftMag_spectralSlope_sma_de_amean'}
# 101
# {'audSpec_Rfilt_sma[0]_amean', 'audspec_lengthL1norm_sma_de_stddev', 'audSpec_Rfilt_sma[18]_amean', 'audSpec_Rfilt_sma[4]_stddev', 'pcm_fftMag_spectralRollOff25.0_sma_amean', 'audSpec_Rfilt_sma[5]_amean', 'shimmerLocal_sma_de_amean', 'audSpec_Rfilt_sma[2]_stddev', 'audSpec_Rfilt_sma_de[2]_stddev', 'audSpec_Rfilt_sma_de[23]_stddev', 'audSpec_Rfilt_sma[0]_stddev', 'audspecRasta_lengthL1norm_sma_stddev', 'audSpec_Rfilt_sma[3]_amean', 'audSpec_Rfilt_sma[21]_amean', 'audSpec_Rfilt_sma[11]_stddev', 'F0final_sma_amean', 'audSpec_Rfilt_sma_de[18]_stddev', 'pcm_fftMag_spectralSkewness_sma_de_stddev', 'audSpec_Rfilt_sma[10]_amean', 'audSpec_Rfilt_sma[7]_amean', 'voicingFinalUnclipped_sma_de_stddev', 'pcm_RMSenergy_sma_amean', 'voicingFinalUnclipped_sma_amean', 'audSpec_Rfilt_sma_de[24]_stddev', 'jitterLocal_sma_amean', 'pcm_fftMag_spectralSlope_sma_stddev', 'pcm_fftMag_spectralRollOff75.0_sma_amean', 'audSpec_Rfilt_sma_de[8]_stddev', 'audSpec_Rfilt_sma[24]_stddev', 'audSpec_Rfilt_sma_de[22]_stddev', 'audSpec_Rfilt_sma[12]_stddev', 'pcm_fftMag_spectralVariance_sma_stddev', 'audSpec_Rfilt_sma[10]_stddev', 'shimmerLocal_sma_de_stddev', 'pcm_fftMag_spectralVariance_sma_de_stddev', 'audSpec_Rfilt_sma[20]_stddev', 'pcm_fftMag_spectralRollOff50.0_sma_stddev', 'jitterLocal_sma_de_stddev', 'pcm_fftMag_psySharpness_sma_amean', 'pcm_fftMag_spectralRollOff25.0_sma_stddev', 'audSpec_Rfilt_sma_de[16]_stddev', 'audspecRasta_lengthL1norm_sma_amean', 'audSpec_Rfilt_sma[9]_stddev', 'audSpec_Rfilt_sma[21]_stddev', 'pcm_fftMag_spectralCentroid_sma_stddev', 'audSpec_Rfilt_sma_de[19]_stddev', 'F0final_sma_stddev', 'F0final_sma_de_stddev', 'jitterDDP_sma_amean', 'pcm_fftMag_spectralHarmonicity_sma_stddev', 'audSpec_Rfilt_sma_de[9]_stddev', 'pcm_fftMag_fband1000-4000_sma_stddev', 'audSpec_Rfilt_sma_de[17]_stddev', 'audSpec_Rfilt_sma_de[13]_stddev', 'pcm_RMSenergy_sma_de_stddev', 'pcm_fftMag_spectralSkewness_sma_stddev', 'shimmerLocal_sma_stddev', 'pcm_fftMag_spectralFlux_sma_amean', 'pcm_RMSenergy_sma_stddev', 'audSpec_Rfilt_sma[15]_amean', 'audSpec_Rfilt_sma[4]_amean', 'pcm_fftMag_spectralSlope_sma_de_stddev', 'audSpec_Rfilt_sma[15]_stddev', 'audSpec_Rfilt_sma[19]_amean', 'pcm_fftMag_spectralRollOff25.0_sma_de_stddev', 'audSpec_Rfilt_sma[9]_amean', 'audSpec_Rfilt_sma[14]_stddev', 'pcm_fftMag_fband250-650_sma_de_stddev', 'audSpec_Rfilt_sma_de[20]_stddev', 'pcm_fftMag_spectralRollOff90.0_sma_amean', 'pcm_fftMag_spectralFlux_sma_stddev', 'audSpec_Rfilt_sma[3]_stddev', 'pcm_fftMag_spectralEntropy_sma_stddev', 'pcm_fftMag_spectralCentroid_sma_de_stddev', 'logHNR_sma_amean', 'audSpec_Rfilt_sma_de[11]_stddev', 'pcm_fftMag_spectralCentroid_sma_amean', 'audSpec_Rfilt_sma_de[0]_stddev', 'audSpec_Rfilt_sma[16]_amean', 'audSpec_Rfilt_sma[20]_amean', 'audSpec_Rfilt_sma_de[25]_stddev', 'pcm_fftMag_psySharpness_sma_stddev', 'audSpec_Rfilt_sma_de[7]_stddev', 'pcm_fftMag_spectralSlope_sma_amean', 'audspec_lengthL1norm_sma_amean', 'audSpec_Rfilt_sma[8]_amean', 'audSpec_Rfilt_sma[14]_amean', 'audSpec_Rfilt_sma_de[6]_stddev', 'pcm_fftMag_spectralFlux_sma_de_stddev', 'audSpec_Rfilt_sma[16]_stddev', 'audspecRasta_lengthL1norm_sma_de_stddev', 'audSpec_Rfilt_sma_de[15]_stddev', 'audSpec_Rfilt_sma[6]_stddev', 'audSpec_Rfilt_sma[22]_stddev', 'audSpec_Rfilt_sma[17]_stddev', 'audSpec_Rfilt_sma[18]_stddev', 'audSpec_Rfilt_sma_de[21]_stddev', 'F0final_sma_de_amean', 'audSpec_Rfilt_sma[25]_amean', 'logHNR_sma_stddev', 'audSpec_Rfilt_sma[25]_stddev', 'jitterLocal_sma_de_amean', 'pcm_zcr_sma_de_stddev', 'audSpec_Rfilt_sma[13]_amean', 'pcm_fftMag_fband1000-4000_sma_amean', 'audSpec_Rfilt_sma_de[1]_stddev', 'pcm_fftMag_spectralRollOff75.0_sma_de_stddev', 'audSpec_Rfilt_sma[5]_stddev', 'logHNR_sma_de_amean', 'pcm_fftMag_fband250-650_sma_stddev', 'audSpec_Rfilt_sma[23]_amean', 'audSpec_Rfilt_sma[11]_amean', 'jitterDDP_sma_de_stddev', 'audSpec_Rfilt_sma_de[4]_stddev', 'audSpec_Rfilt_sma_de[10]_stddev', 'pcm_fftMag_spectralKurtosis_sma_de_stddev', 'jitterLocal_sma_stddev', 'jitterDDP_sma_stddev',  ...
# 159
# ['pcm_fftMag_mfcc_sma_de[4]_amean', 'audSpec_Rfilt_sma_de[25]_amean', 'pcm_fftMag_mfcc_sma_de[13]_amean', 'audSpec_Rfilt_sma_de[0]_amean', 'pcm_fftMag_spectralRollOff90.0_sma_de_amean', 'pcm_fftMag_mfcc_sma[11]_stddev', 'audSpec_Rfilt_sma_de[2]_amean', 'pcm_fftMag_mfcc_sma[4]_stddev', 'pcm_fftMag_mfcc_sma_de[8]_amean', 'pcm_fftMag_mfcc_sma_de[7]_amean', 'pcm_fftMag_mfcc_sma_de[9]_stddev', 'pcm_fftMag_spectralVariance_sma_de_amean', 'audSpec_Rfilt_sma_de[4]_amean', 'pcm_fftMag_mfcc_sma[5]_stddev', 'pcm_fftMag_mfcc_sma[7]_amean', 'pcm_fftMag_mfcc_sma_de[14]_stddev', 'pcm_fftMag_mfcc_sma[14]_amean', 'audspecRasta_lengthL1norm_sma_de_amean', 'pcm_fftMag_mfcc_sma_de[2]_amean', 'pcm_fftMag_mfcc_sma[7]_stddev', 'pcm_fftMag_mfcc_sma[12]_stddev', 'pcm_RMSenergy_sma_de_amean', 'pcm_fftMag_spectralEntropy_sma_de_amean', 'pcm_fftMag_mfcc_sma_de[6]_stddev', 'pcm_fftMag_mfcc_sma[14]_stddev', 'audSpec_Rfilt_sma_de[14]_amean', 'pcm_fftMag_mfcc_sma_de[10]_amean', 'pcm_fftMag_spectralRollOff25.0_sma_de_amean', 'pcm_fftMag_mfcc_sma[10]_amean', 'pcm_fftMag_mfcc_sma[2]_amean', 'pcm_fftMag_mfcc_sma_de[7]_stddev', 'pcm_fftMag_mfcc_sma[11]_amean', 'audSpec_Rfilt_sma_de[16]_amean', 'pcm_fftMag_mfcc_sma[13]_amean', 'audSpec_Rfilt_sma_de[18]_amean', 'pcm_fftMag_mfcc_sma[6]_amean', 'pcm_zcr_sma_de_amean', 'pcm_fftMag_mfcc_sma[9]_stddev', 'audSpec_Rfilt_sma_de[20]_amean', 'pcm_fftMag_mfcc_sma[4]_amean', 'pcm_fftMag_psySharpness_sma_de_amean', 'audSpec_Rfilt_sma_de[22]_amean', 'audSpec_Rfilt_sma_de[8]_amean', 'audSpec_Rfilt_sma_de[23]_amean', 'pcm_fftMag_mfcc_sma[13]_stddev', 'pcm_fftMag_spectralRollOff50.0_sma_de_amean', 'pcm_fftMag_spectralSkewness_sma_de_amean', 'pcm_fftMag_mfcc_sma[3]_amean', 'audSpec_Rfilt_sma_de[21]_amean', 'pcm_fftMag_mfcc_sma[8]_amean', 'pcm_fftMag_mfcc_sma_de[1]_stddev', 'pcm_fftMag_spectralKurtosis_sma_de_amean', 'audSpec_Rfilt_sma_de[11]_amean', 'audSpec_Rfilt_sma_de[12]_amean', 'audSpec_Rfilt_sma_de[15]_amean', 'audSpec_Rfilt_sma_de[19]_amean', 'pcm_fftMag_mfcc_sma[1]_stddev', 'pcm_fftMag_mfcc_sma_de[6]_amean', 'pcm_fftMag_mfcc_sma_de[8]_stddev', 'pcm_fftMag_mfcc_sma_de[10]_stddev', 'pcm_fftMag_fband250-650_sma_de_amean', 'pcm_fftMag_mfcc_sma[5]_amean', 'pcm_fftMag_mfcc_sma[8]_stddev', 'pcm_fftMag_mfcc_sma_de[9]_amean', 'audSpec_Rfilt_sma_de[3]_amean', 'pcm_fftMag_mfcc_sma[6]_stddev', 'pcm_fftMag_mfcc_sma_de[2]_stddev', 'pcm_fftMag_mfcc_sma_de[3]_stddev', 'audspec_lengthL1norm_sma_de_amean', 'pcm_fftMag_spectralCentroid_sma_de_amean', 'pcm_fftMag_mfcc_sma_de[12]_amean', 'pcm_fftMag_mfcc_sma[3]_stddev', 'pcm_fftMag_mfcc_sma_de[5]_stddev', 'pcm_fftMag_spectralFlux_sma_de_amean', 'audSpec_Rfilt_sma_de[1]_amean', 'audSpec_Rfilt_sma_de[24]_amean', 'pcm_fftMag_mfcc_sma_de[3]_amean', 'audSpec_Rfilt_sma_de[17]_amean', 'pcm_fftMag_mfcc_sma_de[1]_amean', 'pcm_fftMag_mfcc_sma_de[11]_stddev', 'pcm_fftMag_mfcc_sma_de[14]_amean', 'pcm_fftMag_mfcc_sma_de[4]_stddev', 'audSpec_Rfilt_sma_de[7]_amean', 'audSpec_Rfilt_sma_de[6]_amean', 'pcm_fftMag_mfcc_sma[2]_stddev', 'pcm_fftMag_mfcc_sma[12]_amean', 'audSpec_Rfilt_sma_de[5]_amean', 'audSpec_Rfilt_sma_de[9]_amean', 'pcm_fftMag_mfcc_sma[1]_amean', 'pcm_fftMag_mfcc_sma[10]_stddev', 'pcm_fftMag_fband1000-4000_sma_de_amean', 'pcm_fftMag_mfcc_sma_de[5]_amean', 'pcm_fftMag_mfcc_sma_de[11]_amean', 'audSpec_Rfilt_sma_de[13]_amean', 'pcm_fftMag_mfcc_sma[9]_amean', 'pcm_fftMag_spectralHarmonicity_sma_de_amean', 'pcm_fftMag_spectralRollOff75.0_sma_de_amean', 'audSpec_Rfilt_sma_de[10]_amean', 'pcm_fftMag_mfcc_sma_de[13]_stddev', 'pcm_fftMag_mfcc_sma_de[12]_stddev', 'pcm_fftMag_spectralSlope_sma_de_amean', 'Arousal_Value', 'Valence_Value', 'frameTime']
# 104
# 1802
# Epoch 1/25
# 2654/2654 [==============================] - 57s 18ms/step - loss: 0.0424 - val_loss: 0.0422
# Epoch 2/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0381 - val_loss: 0.0405
# Epoch 3/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0368 - val_loss: 0.0389
# Epoch 4/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0358 - val_loss: 0.0403
# Epoch 5/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0346 - val_loss: 0.0370
# Epoch 6/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0338 - val_loss: 0.0360
# Epoch 7/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0329 - val_loss: 0.0359
# Epoch 8/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0321 - val_loss: 0.0344
# Epoch 9/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0315 - val_loss: 0.0334
# Epoch 10/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0307 - val_loss: 0.0340
# Epoch 11/25
# 2654/2654 [==============================] - 46s 18ms/step - loss: 0.0300 - val_loss: 0.0319
# Epoch 12/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0294 - val_loss: 0.0323
# Epoch 13/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0286 - val_loss: 0.0314
# Epoch 14/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0280 - val_loss: 0.0313
# Epoch 15/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0273 - val_loss: 0.0310
# Epoch 16/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0267 - val_loss: 0.0299
# Epoch 17/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0261 - val_loss: 0.0307
# Epoch 18/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0257 - val_loss: 0.0295
# Epoch 19/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0252 - val_loss: 0.0287
# Epoch 20/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0247 - val_loss: 0.0284
# Epoch 21/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0241 - val_loss: 0.0281
# Epoch 22/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0237 - val_loss: 0.0279
# Epoch 23/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0232 - val_loss: 0.0277
# Epoch 24/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0227 - val_loss: 0.0275
# Epoch 25/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0224 - val_loss: 0.0271
# 332/332 [==============================] - 3s 7ms/step
# Epoch 1/25
# 2654/2654 [==============================] - 51s 18ms/step - loss: 0.0426 - val_loss: 0.0438
# Epoch 2/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0385 - val_loss: 0.0400
# Epoch 3/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0370 - val_loss: 0.0384
# Epoch 4/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0359 - val_loss: 0.0375
# Epoch 5/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0349 - val_loss: 0.0364
# Epoch 6/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0340 - val_loss: 0.0360
# Epoch 7/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0333 - val_loss: 0.0349
# Epoch 8/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0326 - val_loss: 0.0345
# Epoch 9/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0317 - val_loss: 0.0340
# Epoch 10/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0313 - val_loss: 0.0347
# Epoch 11/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0305 - val_loss: 0.0328
# Epoch 12/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0299 - val_loss: 0.0323
# Epoch 13/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0294 - val_loss: 0.0322
# Epoch 14/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0287 - val_loss: 0.0316
# Epoch 15/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0280 - val_loss: 0.0309
# Epoch 16/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0276 - val_loss: 0.0304
# Epoch 17/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0270 - val_loss: 0.0300
# Epoch 18/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0264 - val_loss: 0.0301
# Epoch 19/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0260 - val_loss: 0.0289
# Epoch 20/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0254 - val_loss: 0.0284
# Epoch 21/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0249 - val_loss: 0.0278
# Epoch 22/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0246 - val_loss: 0.0283
# Epoch 23/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0242 - val_loss: 0.0277
# Epoch 24/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0238 - val_loss: 0.0296
# Epoch 25/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0233 - val_loss: 0.0280
# 332/332 [==============================] - 2s 6ms/step
# Epoch 1/25
# 2654/2654 [==============================] - 51s 18ms/step - loss: 0.0425 - val_loss: 0.0461
# Epoch 2/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0383 - val_loss: 0.0396
# Epoch 3/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0368 - val_loss: 0.0380
# Epoch 4/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0357 - val_loss: 0.0370
# Epoch 5/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0348 - val_loss: 0.0363
# Epoch 6/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0341 - val_loss: 0.0353
# Epoch 7/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0331 - val_loss: 0.0357
# Epoch 8/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0323 - val_loss: 0.0336
# Epoch 9/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0315 - val_loss: 0.0336
# Epoch 10/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0307 - val_loss: 0.0327
# Epoch 11/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0300 - val_loss: 0.0331
# Epoch 12/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0293 - val_loss: 0.0311
# Epoch 13/25
# 2654/2654 [==============================] - 51s 19ms/step - loss: 0.0286 - val_loss: 0.0310
# Epoch 14/25
# 2654/2654 [==============================] - 53s 20ms/step - loss: 0.0282 - val_loss: 0.0305
# Epoch 15/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0273 - val_loss: 0.0299
# Epoch 16/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0267 - val_loss: 0.0295
# Epoch 17/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0261 - val_loss: 0.0294
# Epoch 18/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0255 - val_loss: 0.0292
# Epoch 19/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0250 - val_loss: 0.0285
# Epoch 20/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0244 - val_loss: 0.0286
# Epoch 21/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0239 - val_loss: 0.0278
# Epoch 22/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0234 - val_loss: 0.0278
# Epoch 23/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0230 - val_loss: 0.0271
# Epoch 24/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0226 - val_loss: 0.0277
# Epoch 25/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0221 - val_loss: 0.0273
# 332/332 [==============================] - 3s 7ms/step
# Epoch 1/25
# 2654/2654 [==============================] - 53s 18ms/step - loss: 0.0425 - val_loss: 0.0460
# Epoch 2/25
# 2654/2654 [==============================] - 49s 19ms/step - loss: 0.0384 - val_loss: 0.0406
# Epoch 3/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0371 - val_loss: 0.0389
# Epoch 4/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0359 - val_loss: 0.0372
# Epoch 5/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0349 - val_loss: 0.0376
# Epoch 6/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0342 - val_loss: 0.0357
# Epoch 7/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0334 - val_loss: 0.0355
# Epoch 8/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0327 - val_loss: 0.0353
# Epoch 9/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0321 - val_loss: 0.0348
# Epoch 10/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0314 - val_loss: 0.0340
# Epoch 11/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0307 - val_loss: 0.0329
# Epoch 12/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0301 - val_loss: 0.0323
# Epoch 13/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0294 - val_loss: 0.0314
# Epoch 14/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0288 - val_loss: 0.0311
# Epoch 15/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0283 - val_loss: 0.0303
# Epoch 16/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0277 - val_loss: 0.0316
# Epoch 17/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0272 - val_loss: 0.0300
# Epoch 18/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0266 - val_loss: 0.0285
# Epoch 19/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0261 - val_loss: 0.0283
# Epoch 20/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0257 - val_loss: 0.0283
# Epoch 21/25
# 2654/2654 [==============================] - 45s 17ms/step - loss: 0.0251 - val_loss: 0.0280
# Epoch 22/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0246 - val_loss: 0.0292
# Epoch 23/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0243 - val_loss: 0.0274
# Epoch 24/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0238 - val_loss: 0.0271
# Epoch 25/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0235 - val_loss: 0.0270
# 332/332 [==============================] - 3s 7ms/step
# Epoch 1/25
# 2654/2654 [==============================] - 51s 18ms/step - loss: 0.0421 - val_loss: 0.0425
# Epoch 2/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0379 - val_loss: 0.0436
# Epoch 3/25
# 2654/2654 [==============================] - 46s 18ms/step - loss: 0.0366 - val_loss: 0.0405
# Epoch 4/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0355 - val_loss: 0.0424
# Epoch 5/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0346 - val_loss: 0.0373
# Epoch 6/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0338 - val_loss: 0.0363
# Epoch 7/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0330 - val_loss: 0.0362
# Epoch 8/25
# 2654/2654 [==============================] - 46s 18ms/step - loss: 0.0321 - val_loss: 0.0357
# Epoch 9/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0314 - val_loss: 0.0344
# Epoch 10/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0306 - val_loss: 0.0343
# Epoch 11/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0300 - val_loss: 0.0323
# Epoch 12/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0294 - val_loss: 0.0317
# Epoch 13/25
# 2654/2654 [==============================] - 49s 19ms/step - loss: 0.0287 - val_loss: 0.0319
# Epoch 14/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0281 - val_loss: 0.0315
# Epoch 15/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0276 - val_loss: 0.0312
# Epoch 16/25
# 2654/2654 [==============================] - 50s 19ms/step - loss: 0.0269 - val_loss: 0.0303
# Epoch 17/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0264 - val_loss: 0.0308
# Epoch 18/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0260 - val_loss: 0.0292
# Epoch 19/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0254 - val_loss: 0.0286
# Epoch 20/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0248 - val_loss: 0.0292
# Epoch 21/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0244 - val_loss: 0.0284
# Epoch 22/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0239 - val_loss: 0.0285
# Epoch 23/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0234 - val_loss: 0.0276
# Epoch 24/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0230 - val_loss: 0.0280
# Epoch 25/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0226 - val_loss: 0.0276
# 332/332 [==============================] - 2s 7ms/step
# Average Arousal MSE: 0.0244
# Average Arousal MAE: 0.1213
# Average Arousal RMSE: 0.1563
# Average Arousal R2 Score: 0.5576
# Average Arousal F1 Score: 0.8587
# Average Arousal Accuracy: 0.8041
# Average Arousal Precision: 0.8463
# Average Arousal Recall: 0.8718
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
