# %%
import pandas as pd
import numpy as np
import glob
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, f1_score, accuracy_score, precision_score, recall_score
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'

# %%
# Get a list of all feature file paths in the directory
feature_files = glob.glob(directory_path + '/*.csv')

# %%
# Define lists to store the feature and target data
X = []
y_a = []
y_v = []

# %%
# Iterate over each feature file
for file in feature_files:
    # Read the feature file into a DataFrame
    df = pd.read_csv(file)

    # Extract the features and target variables
    features = df.drop(['Arousal_Value', 'Valence_Value', 'frameTime'], axis=1).values
    arousal = df['Arousal_Value'].values
    valence = df['Valence_Value'].values

    # Append the data to the lists
    X.append(features)
    y_a.append(arousal)
    y_v.append(valence)

# %%
# Concatenate the feature and target arrays
X = np.concatenate(X)
y_a = np.concatenate(y_a)
y_v = np.concatenate(y_v)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape the input data for LSTM
X_reshaped = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

# %%
# Define the number of folds for cross-validation
num_folds = 5

# Initialize lists to store evaluation results
mse_v = []
mae_v = []
rmse_v = []
r2_v = []
f1_v = []
accuracy_v = []
precision_v = []
recall_v = []

# %%
# Perform tenfold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(X_reshaped):
    X_train, X_val = X_reshaped[train_index], X_reshaped[test_index]
    y_v_train, y_v_val = y_v[train_index], y_v[test_index]

    # Split the validation set further into val and test sets
    val_size = len(X_val) // 2
    X_val, X_test = X_val[:val_size], X_val[val_size:]
    y_v_val, y_v_test = y_v_val[:val_size], y_v_val[val_size:]

    # Build and compile the BiLSTM model for Arousal
    model_v = Sequential()
    model_v.add(Bidirectional(CuDNNLSTM(64, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))  # Adapt input shape
    model_v.add(Flatten())
    model_v.add(Dense(1))
    model_v.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

    # Train the Arousal model with validation
    model_v.fit(X_train, y_v_train, validation_data=(X_val, y_v_val), epochs=25, batch_size=32)

    # Evaluate the model on the test set
    predictions_v = model_v.predict(X_test)


    # Calculate additional evaluation metrics
    mse_v.append(mean_squared_error(y_v_test, predictions_v))
    mae_v.append(mean_absolute_error(y_v_test, predictions_v))
    rmse_v.append(np.sqrt(mean_squared_error(y_v_test, predictions_v)))
    r2_v.append(r2_score(y_v_test, predictions_v))

    # Convert regression predictions to binary labels
    threshold = 0
    binary_predictions_v = (predictions_v >= threshold).astype(int)
    y_v_test_binary = (y_v_test >= threshold).astype(int)

    # Calculate F1-score, accuracy, precision, and recall for binary classification
    f1_v.append(f1_score(y_v_test_binary, binary_predictions_v))
    accuracy_v.append(accuracy_score(y_v_test_binary, binary_predictions_v))
    precision_v.append(precision_score(y_v_test_binary, binary_predictions_v))
    recall_v.append(recall_score(y_v_test_binary, binary_predictions_v))
# Out:
# Epoch 1/25
# 2654/2654 [==============================] - 57s 18ms/step - loss: 0.0437 - val_loss: 0.0435
# Epoch 2/25
# 2654/2654 [==============================] - 49s 19ms/step - loss: 0.0401 - val_loss: 0.0421
# Epoch 3/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0391 - val_loss: 0.0419
# Epoch 4/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0386 - val_loss: 0.0424
# Epoch 5/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0382 - val_loss: 0.0430
# Epoch 6/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0378 - val_loss: 0.0412
# Epoch 7/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0376 - val_loss: 0.0408
# Epoch 8/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0373 - val_loss: 0.0415
# Epoch 9/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0371 - val_loss: 0.0416
# Epoch 10/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0370 - val_loss: 0.0416
# Epoch 11/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0369 - val_loss: 0.0403
# Epoch 12/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0368 - val_loss: 0.0417
# Epoch 13/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0365 - val_loss: 0.0398
# Epoch 14/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0365 - val_loss: 0.0424
# Epoch 15/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0364 - val_loss: 0.0398
# Epoch 16/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0364 - val_loss: 0.0411
# Epoch 17/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0364 - val_loss: 0.0446
# Epoch 18/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0363 - val_loss: 0.0402
# Epoch 19/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0361 - val_loss: 0.0400
# Epoch 20/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0361 - val_loss: 0.0394
# Epoch 21/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0360 - val_loss: 0.0445
# Epoch 22/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0360 - val_loss: 0.0396
# Epoch 23/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0359 - val_loss: 0.0403
# Epoch 24/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0358 - val_loss: 0.0391
# Epoch 25/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0357 - val_loss: 0.0403
# 332/332 [==============================] - 3s 7ms/step
# Epoch 1/25
# 2654/2654 [==============================] - 50s 18ms/step - loss: 0.0436 - val_loss: 0.0486
# Epoch 2/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0401 - val_loss: 0.0462
# Epoch 3/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0391 - val_loss: 0.0421
# Epoch 4/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0385 - val_loss: 0.0417
# Epoch 5/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0380 - val_loss: 0.0432
# Epoch 6/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0376 - val_loss: 0.0408
# Epoch 7/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0375 - val_loss: 0.0416
# Epoch 8/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0373 - val_loss: 0.0421
# Epoch 9/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0372 - val_loss: 0.0415
# Epoch 10/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0371 - val_loss: 0.0404
# Epoch 11/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0369 - val_loss: 0.0410
# Epoch 12/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0369 - val_loss: 0.0407
# Epoch 13/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0367 - val_loss: 0.0404
# Epoch 14/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0366 - val_loss: 0.0403
# Epoch 15/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0366 - val_loss: 0.0405
# Epoch 16/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0364 - val_loss: 0.0418
# Epoch 17/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0364 - val_loss: 0.0403
# Epoch 18/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0362 - val_loss: 0.0396
# Epoch 19/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0361 - val_loss: 0.0400
# Epoch 20/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0362 - val_loss: 0.0403
# Epoch 21/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0361 - val_loss: 0.0395
# Epoch 22/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0359 - val_loss: 0.0410
# Epoch 23/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0359 - val_loss: 0.0396
# Epoch 24/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0358 - val_loss: 0.0398
# Epoch 25/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0358 - val_loss: 0.0408
# 332/332 [==============================] - 3s 7ms/step
# Epoch 1/25
# 2654/2654 [==============================] - 50s 18ms/step - loss: 0.0441 - val_loss: 0.0448
# Epoch 2/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0404 - val_loss: 0.0431
# Epoch 3/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0394 - val_loss: 0.0418
# Epoch 4/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0387 - val_loss: 0.0412
# Epoch 5/25
# 2654/2654 [==============================] - 49s 19ms/step - loss: 0.0383 - val_loss: 0.0407
# Epoch 6/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0379 - val_loss: 0.0400
# Epoch 7/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0378 - val_loss: 0.0414
# Epoch 8/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0375 - val_loss: 0.0400
# Epoch 9/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0374 - val_loss: 0.0399
# Epoch 10/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0372 - val_loss: 0.0395
# Epoch 11/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0371 - val_loss: 0.0407
# Epoch 12/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0370 - val_loss: 0.0395
# Epoch 13/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0369 - val_loss: 0.0392
# Epoch 14/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0367 - val_loss: 0.0405
# Epoch 15/25
# 2654/2654 [==============================] - 49s 19ms/step - loss: 0.0366 - val_loss: 0.0398
# Epoch 16/25
# 2654/2654 [==============================] - 50s 19ms/step - loss: 0.0365 - val_loss: 0.0412
# Epoch 17/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0364 - val_loss: 0.0396
# Epoch 18/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0364 - val_loss: 0.0397
# Epoch 19/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0363 - val_loss: 0.0388
# Epoch 20/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0362 - val_loss: 0.0395
# Epoch 21/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0361 - val_loss: 0.0404
# Epoch 22/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0360 - val_loss: 0.0384
# Epoch 23/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0360 - val_loss: 0.0393
# Epoch 24/25
# 2654/2654 [==============================] - 46s 18ms/step - loss: 0.0359 - val_loss: 0.0385
# Epoch 25/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0358 - val_loss: 0.0382
# 332/332 [==============================] - 2s 7ms/step
# Epoch 1/25
# 2654/2654 [==============================] - 50s 18ms/step - loss: 0.0439 - val_loss: 0.0435
# Epoch 2/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0402 - val_loss: 0.0426
# Epoch 3/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0394 - val_loss: 0.0415
# Epoch 4/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0387 - val_loss: 0.0414
# Epoch 5/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0381 - val_loss: 0.0405
# Epoch 6/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0379 - val_loss: 0.0414
# Epoch 7/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0376 - val_loss: 0.0411
# Epoch 8/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0374 - val_loss: 0.0398
# Epoch 9/25
# 2654/2654 [==============================] - 46s 18ms/step - loss: 0.0373 - val_loss: 0.0435
# Epoch 10/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0372 - val_loss: 0.0469
# Epoch 11/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0370 - val_loss: 0.0402
# Epoch 12/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0369 - val_loss: 0.0399
# Epoch 13/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0369 - val_loss: 0.0399
# Epoch 14/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0367 - val_loss: 0.0439
# Epoch 15/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0366 - val_loss: 0.0393
# Epoch 16/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0366 - val_loss: 0.0395
# Epoch 17/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0364 - val_loss: 0.0394
# Epoch 18/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0363 - val_loss: 0.0399
# Epoch 19/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0363 - val_loss: 0.0389
# Epoch 20/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0363 - val_loss: 0.0389
# Epoch 21/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0361 - val_loss: 0.0405
# Epoch 22/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0361 - val_loss: 0.0393
# Epoch 23/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0360 - val_loss: 0.0398
# Epoch 24/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0360 - val_loss: 0.0386
# Epoch 25/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0359 - val_loss: 0.0397
# 332/332 [==============================] - 3s 7ms/step
# Epoch 1/25
# 2654/2654 [==============================] - 50s 18ms/step - loss: 0.0437 - val_loss: 0.0451
# Epoch 2/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0400 - val_loss: 0.0485
# Epoch 3/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0390 - val_loss: 0.0423
# Epoch 4/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0384 - val_loss: 0.0438
# Epoch 5/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0378 - val_loss: 0.0428
# Epoch 6/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0376 - val_loss: 0.0421
# Epoch 7/25
# 2654/2654 [==============================] - 46s 17ms/step - loss: 0.0373 - val_loss: 0.0409
# Epoch 8/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0371 - val_loss: 0.0412
# Epoch 9/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0369 - val_loss: 0.0409
# Epoch 10/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0368 - val_loss: 0.0418
# Epoch 11/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0367 - val_loss: 0.0404
# Epoch 12/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0365 - val_loss: 0.0408
# Epoch 13/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0364 - val_loss: 0.0409
# Epoch 14/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0363 - val_loss: 0.0404
# Epoch 15/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0363 - val_loss: 0.0405
# Epoch 16/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0361 - val_loss: 0.0440
# Epoch 17/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0360 - val_loss: 0.0403
# Epoch 18/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0360 - val_loss: 0.0416
# Epoch 19/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0359 - val_loss: 0.0401
# Epoch 20/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0358 - val_loss: 0.0401
# Epoch 21/25
# 2654/2654 [==============================] - 49s 18ms/step - loss: 0.0357 - val_loss: 0.0405
# Epoch 22/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0357 - val_loss: 0.0403
# Epoch 23/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0357 - val_loss: 0.0402
# Epoch 24/25
# 2654/2654 [==============================] - 47s 18ms/step - loss: 0.0355 - val_loss: 0.0395
# Epoch 25/25
# 2654/2654 [==============================] - 48s 18ms/step - loss: 0.0354 - val_loss: 0.0407
# 332/332 [==============================] - 3s 7ms/step

# %%
# Calculate average performance across all folds
average_mse_v = np.mean(mse_v)
average_mae_v = np.mean(mae_v)
average_rmse_v = np.mean(rmse_v)
average_r2_v = np.mean(r2_v)
average_f1_v = np.mean(f1_v)
average_accuracy_v = np.mean(accuracy_v)
average_precision_v = np.mean(precision_v)
average_recall_v = np.mean(recall_v)

print(f'Average Valence MSE: {average_mse_v:.4f}')
print(f'Average Valence MAE: {average_mae_v:.4f}')
print(f'Average Valence RMSE: {average_rmse_v:.4f}')
print(f'Average Valence R2 Score: {average_r2_v:.4f}')
print(f'Average Valence F1 Score: {average_f1_v:.4f}')
print(f'Average Valence Accuracy: {average_accuracy_v:.4f}')
print(f'Average Valence Precision: {average_precision_v:.4f}')
print(f'Average Valence Recall: {average_recall_v:.4f}')
# Out:
# Average Valence MSE: 0.0321
# Average Valence MAE: 0.1421
# Average Valence RMSE: 0.1791
# Average Valence R2 Score: 0.4189
# Average Valence F1 Score: 0.8453
# Average Valence Accuracy: 0.7707
# Average Valence Precision: 0.7842
# Average Valence Recall: 0.9170
