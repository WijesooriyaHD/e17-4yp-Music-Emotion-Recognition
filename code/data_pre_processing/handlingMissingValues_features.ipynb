# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import os
import pandas as pd

folder_path = "/content/drive/MyDrive/FYP_dataset/features"
file_names = os.listdir(folder_path)
csv_files = [file_name for file_name in file_names if file_name.endswith(".csv")]
print(len(csv_files))
for i in csv_files:
  if(i=="1805.csv"):
    print(i)
# Out:
# 1802
# 1805.csv

# %%
folder_path = "/content/drive/MyDrive/FYP_dataset/features"
file_names = os.listdir(folder_path)
csv_files = [file_name for file_name in file_names if file_name.endswith(".csv")]

file_path = os.path.join(folder_path, csv_files[0])
data_frame=pd.read_csv(file_path)
initial_colnames=list(data_frame)

for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    data_frame=pd.read_csv(file_path)
    rows,columns=data_frame.shape
    colnames=list(data_frame)
    #print(colnames)
    for i in range(1,len(colnames)):
        #print(colnames[i])
        val = data_frame[colnames[i]].isnull().sum()
        if(val!=0):
            print("CSV File : ",csv_file)
            print(colnames[i]+" : "+str(val))
