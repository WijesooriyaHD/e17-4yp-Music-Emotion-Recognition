# %%
import pandas as pd
import numpy as np
import glob
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, f1_score, accuracy_score, precision_score, recall_score
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'

# Get a list of all feature file paths in the directory
feature_files = glob.glob(directory_path + '/*.csv')

# Define lists to store the feature and target data
X = []
y_a = []
y_v = []

# Iterate over each feature file
for file in feature_files:
    # Read the feature file into a DataFrame
    df = pd.read_csv(file)

    # Extract the features and target variables
    features = df.drop(['Arousal_Value', 'Valence_Value', 'frameTime'], axis=1).values
    arousal = df['Arousal_Value'].values
    valence = df['Valence_Value'].values

    # Append the data to the lists
    X.append(features)
    y_a.append(arousal)
    y_v.append(valence)

# Concatenate the feature and target arrays
X = np.concatenate(X)
y_a = np.concatenate(y_a)
y_v = np.concatenate(y_v)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape the input data for LSTM
X_reshaped = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

# Define the number of folds for cross-validation
num_folds = 2

# Initialize lists to store evaluation results
mse_v = []
mae_v = []
rmse_v = []
r2_v = []
f1_v = []
accuracy_v = []
precision_v = []
recall_v = []
train_mse_v = []
test_mse_v = []
train_accuracy_v = []
test_accuracy_v = []

# Perform tenfold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(X_reshaped):
    X_train, X_val = X_reshaped[train_index], X_reshaped[test_index]
    y_v_train, y_v_val = y_v[train_index], y_v[test_index]

    # Split the validation set further into val and test sets
    val_size = len(X_val) // 2
    X_val, X_test = X_val[:val_size], X_val[val_size:]
    y_v_val, y_v_test = y_v_val[:val_size], y_v_val[val_size:]

    # Build the BiLSTM model for Arousal
    model_v = Sequential()
    model_v.add(Bidirectional(CuDNNLSTM(64, return_sequences=True), input_shape=(X_train.shape[1], 1)))
    model_v.add(Flatten())

    # Add DNN layers with dropout
    dnn_layers = [512, 256, 128, 64]  # Modify this list as needed

    for layer_size in dnn_layers:
        model_v.add(Dense(layer_size, activation='relu'))

    model_v.add(Dense(1))
    model_v.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

    # Train the Arousal model
    model_v.fit(X_train, y_v_train, validation_data=(X_val, y_v_val), epochs=75, batch_size=32)
    threshold = 0
    # Evaluate the model on the training set
    train_predictions_v = model_v.predict(X_train)
    train_mse = mean_squared_error(y_v_train, train_predictions_v)
    train_accuracy = accuracy_score(y_v_train >= threshold, train_predictions_v >= threshold)
    train_mse_v.append(train_mse)
    train_accuracy_v.append(train_accuracy)

    # Evaluate the model on the test set
    test_predictions_v = model_v.predict(X_test)
    test_mse = mean_squared_error(y_v_test, test_predictions_v)
    test_accuracy = accuracy_score(y_v_test >= threshold, test_predictions_v >= threshold)
    test_mse_v.append(test_mse)
    test_accuracy_v.append(test_accuracy)

    # Calculate additional evaluation metrics
    mae_v.append(mean_absolute_error(y_v_test, test_predictions_v))
    rmse_v.append(np.sqrt(test_mse))
    r2_v.append(r2_score(y_v_test, test_predictions_v))

    # Convert regression predictions to binary labels

    binary_predictions_v = (test_predictions_v >= threshold).astype(int)
    y_v_test_binary = (y_v_test >= threshold).astype(int)

    # Calculate F1-score, accuracy, precision, and recall for binary classification
    f1_v.append(f1_score(y_v_test_binary, binary_predictions_v))
    accuracy_v.append(accuracy_score(y_v_test_binary, binary_predictions_v))
    precision_v.append(precision_score(y_v_test_binary, binary_predictions_v))
    recall_v.append(recall_score(y_v_test_binary, binary_predictions_v))

# Calculate average performance across all folds
average_mse_v = np.mean(test_mse_v)
average_mae_v = np.mean(mae_v)
average_rmse_v = np.mean(rmse_v)
average_r2_v = np.mean(r2_v)
average_f1_v = np.mean(f1_v)
average_accuracy_v = np.mean(accuracy_v)
average_precision_v = np.mean(precision_v)
average_recall_v = np.mean(recall_v)

# Calculate average training and test MSE and accuracy across all folds
average_train_mse_v = np.mean(train_mse_v)
average_test_mse_v = np.mean(test_mse_v)
average_train_accuracy_v = np.mean(train_accuracy_v)
average_test_accuracy_v = np.mean(test_accuracy_v)

print(f'Average Valence MSE: {average_mse_v:.4f}')
print(f'Average Valence MAE: {average_mae_v:.4f}')
print(f'Average Valence RMSE: {average_rmse_v:.4f}')
print(f'Average Valence R2 Score: {average_r2_v:.4f}')
print(f'Average Valence F1 Score: {average_f1_v:.4f}')
print(f'Average Valence Accuracy: {average_accuracy_v:.4f}')
print(f'Average Valence Precision: {average_precision_v:.4f}')
print(f'Average Valence Recall: {average_recall_v:.4f}')

print("\n\n")

# Print average training and test MSE and accuracy
print(f'Average Train MSE: {average_train_mse_v:.4f}')
print(f'Average Test MSE: {average_test_mse_v:.4f}')
print(f'Average Train Accuracy: {average_train_accuracy_v:.4f}')
print(f'Average Test Accuracy: {average_test_accuracy_v:.4f}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Epoch 1/75
# 1659/1659 [==============================] - 53s 28ms/step - loss: 0.0454 - val_loss: 0.0466
# Epoch 2/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0407 - val_loss: 0.0429
# Epoch 3/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0388 - val_loss: 0.0404
# Epoch 4/75
# 1659/1659 [==============================] - 47s 29ms/step - loss: 0.0381 - val_loss: 0.0401
# Epoch 5/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0373 - val_loss: 0.0396
# Epoch 6/75
# 1659/1659 [==============================] - 51s 30ms/step - loss: 0.0366 - val_loss: 0.0396
# Epoch 7/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0364 - val_loss: 0.0387
# Epoch 8/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0359 - val_loss: 0.0392
# Epoch 9/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0356 - val_loss: 0.0407
# Epoch 10/75
# 1659/1659 [==============================] - 49s 29ms/step - loss: 0.0352 - val_loss: 0.0379
# Epoch 11/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0349 - val_loss: 0.0378
# Epoch 12/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0345 - val_loss: 0.0372
# Epoch 13/75
# 1659/1659 [==============================] - 49s 29ms/step - loss: 0.0343 - val_loss: 0.0374
# Epoch 14/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0341 - val_loss: 0.0366
# Epoch 15/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0338 - val_loss: 0.0373
# Epoch 16/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0336 - val_loss: 0.0380
# Epoch 17/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0334 - val_loss: 0.0370
# Epoch 18/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0331 - val_loss: 0.0358
# Epoch 19/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0331 - val_loss: 0.0367
# Epoch 20/75
# 1659/1659 [==============================] - 46s 27ms/step - loss: 0.0328 - val_loss: 0.0373
# Epoch 21/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0326 - val_loss: 0.0360
# Epoch 22/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0322 - val_loss: 0.0349
# Epoch 23/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0320 - val_loss: 0.0360
# Epoch 24/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0319 - val_loss: 0.0365
# Epoch 25/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0315 - val_loss: 0.0355
# Epoch 26/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0312 - val_loss: 0.0359
# Epoch 27/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0310 - val_loss: 0.0345
# Epoch 28/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0308 - val_loss: 0.0349
# Epoch 29/75
# 1659/1659 [==============================] - 49s 29ms/step - loss: 0.0305 - val_loss: 0.0345
# Epoch 30/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0301 - val_loss: 0.0346
# Epoch 31/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0300 - val_loss: 0.0340
# Epoch 32/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0297 - val_loss: 0.0345
# Epoch 33/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0294 - val_loss: 0.0337
# Epoch 34/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0292 - val_loss: 0.0340
# Epoch 35/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0290 - val_loss: 0.0344
# Epoch 36/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0288 - val_loss: 0.0329
# Epoch 37/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0285 - val_loss: 0.0335
# Epoch 38/75
# 1659/1659 [==============================] - 49s 29ms/step - loss: 0.0282 - val_loss: 0.0345
# Epoch 39/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0280 - val_loss: 0.0327
# Epoch 40/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0278 - val_loss: 0.0332
# Epoch 41/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0276 - val_loss: 0.0330
# Epoch 42/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0273 - val_loss: 0.0326
# Epoch 43/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0272 - val_loss: 0.0342
# Epoch 44/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0268 - val_loss: 0.0331
# Epoch 45/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0267 - val_loss: 0.0326
# Epoch 46/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0264 - val_loss: 0.0325
# Epoch 47/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0263 - val_loss: 0.0326
# Epoch 48/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0260 - val_loss: 0.0329
# Epoch 49/75
# 1659/1659 [==============================] - 51s 31ms/step - loss: 0.0258 - val_loss: 0.0320
# Epoch 50/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0255 - val_loss: 0.0317
# Epoch 51/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0255 - val_loss: 0.0317
# Epoch 52/75
# 1659/1659 [==============================] - 47s 29ms/step - loss: 0.0253 - val_loss: 0.0340
# Epoch 53/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0249 - val_loss: 0.0315
# Epoch 54/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0246 - val_loss: 0.0323
# Epoch 55/75
# 1659/1659 [==============================] - 47s 29ms/step - loss: 0.0246 - val_loss: 0.0314
# Epoch 56/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0243 - val_loss: 0.0320
# Epoch 57/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0242 - val_loss: 0.0312
# Epoch 58/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0239 - val_loss: 0.0309
# Epoch 59/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0239 - val_loss: 0.0305
# Epoch 60/75
# 1659/1659 [==============================] - 47s 29ms/step - loss: 0.0235 - val_loss: 0.0311
# Epoch 61/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0234 - val_loss: 0.0309
# Epoch 62/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0231 - val_loss: 0.0311
# Epoch 63/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0230 - val_loss: 0.0307
# Epoch 64/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0228 - val_loss: 0.0307
# Epoch 65/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0226 - val_loss: 0.0309
# Epoch 66/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0223 - val_loss: 0.0311
# Epoch 67/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0222 - val_loss: 0.0312
# Epoch 68/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0220 - val_loss: 0.0306
# Epoch 69/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0219 - val_loss: 0.0305
# Epoch 70/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0218 - val_loss: 0.0308
# Epoch 71/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0214 - val_loss: 0.0309
# Epoch 72/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0214 - val_loss: 0.0303
# Epoch 73/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0212 - val_loss: 0.0307
# Epoch 74/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0211 - val_loss: 0.0301
# Epoch 75/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0208 - val_loss: 0.0311
# 1659/1659 [==============================] - 16s 10ms/step
# 830/830 [==============================] - 9s 11ms/step
# Epoch 1/75
# 1659/1659 [==============================] - 52s 29ms/step - loss: 0.0453 - val_loss: 0.0440
# Epoch 2/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0404 - val_loss: 0.0424
# Epoch 3/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0390 - val_loss: 0.0405
# Epoch 4/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0379 - val_loss: 0.0401
# Epoch 5/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0369 - val_loss: 0.0396
# Epoch 6/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0363 - val_loss: 0.0382
# Epoch 7/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0355 - val_loss: 0.0387
# Epoch 8/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0351 - val_loss: 0.0395
# Epoch 9/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0346 - val_loss: 0.0380
# Epoch 10/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0342 - val_loss: 0.0369
# Epoch 11/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0336 - val_loss: 0.0369
# Epoch 12/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0331 - val_loss: 0.0366
# Epoch 13/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0327 - val_loss: 0.0356
# Epoch 14/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0323 - val_loss: 0.0357
# Epoch 15/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0318 - val_loss: 0.0350
# Epoch 16/75
# 1659/1659 [==============================] - 47s 29ms/step - loss: 0.0314 - val_loss: 0.0346
# Epoch 17/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0312 - val_loss: 0.0356
# Epoch 18/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0307 - val_loss: 0.0341
# Epoch 19/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0303 - val_loss: 0.0343
# Epoch 20/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0301 - val_loss: 0.0338
# Epoch 21/75
# 1659/1659 [==============================] - 47s 29ms/step - loss: 0.0297 - val_loss: 0.0336
# Epoch 22/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0294 - val_loss: 0.0332
# Epoch 23/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0289 - val_loss: 0.0338
# Epoch 24/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0286 - val_loss: 0.0338
# Epoch 25/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0282 - val_loss: 0.0340
# Epoch 26/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0279 - val_loss: 0.0318
# Epoch 27/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0275 - val_loss: 0.0324
# Epoch 28/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0273 - val_loss: 0.0322
# Epoch 29/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0269 - val_loss: 0.0331
# Epoch 30/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0266 - val_loss: 0.0330
# Epoch 31/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0262 - val_loss: 0.0315
# Epoch 32/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0260 - val_loss: 0.0317
# Epoch 33/75
# 1659/1659 [==============================] - 47s 29ms/step - loss: 0.0256 - val_loss: 0.0304
# Epoch 34/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0253 - val_loss: 0.0314
# Epoch 35/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0252 - val_loss: 0.0318
# Epoch 36/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0247 - val_loss: 0.0309
# Epoch 37/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0244 - val_loss: 0.0302
# Epoch 38/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0241 - val_loss: 0.0309
# Epoch 39/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0238 - val_loss: 0.0296
# Epoch 40/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0236 - val_loss: 0.0300
# Epoch 41/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0233 - val_loss: 0.0304
# Epoch 42/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0229 - val_loss: 0.0296
# Epoch 43/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0227 - val_loss: 0.0307
# Epoch 44/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0225 - val_loss: 0.0297
# Epoch 45/75
# 1659/1659 [==============================] - 47s 29ms/step - loss: 0.0221 - val_loss: 0.0299
# Epoch 46/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0219 - val_loss: 0.0296
# Epoch 47/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0216 - val_loss: 0.0293
# Epoch 48/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0215 - val_loss: 0.0301
# Epoch 49/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0212 - val_loss: 0.0291
# Epoch 50/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0209 - val_loss: 0.0291
# Epoch 51/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0207 - val_loss: 0.0295
# Epoch 52/75
# 1659/1659 [==============================] - 47s 29ms/step - loss: 0.0204 - val_loss: 0.0290
# Epoch 53/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0202 - val_loss: 0.0290
# Epoch 54/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0200 - val_loss: 0.0289
# Epoch 55/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0197 - val_loss: 0.0284
# Epoch 56/75
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0195 - val_loss: 0.0293
# Epoch 57/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0193 - val_loss: 0.0288
# Epoch 58/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0191 - val_loss: 0.0281
# Epoch 59/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0188 - val_loss: 0.0282
# Epoch 60/75
# 1659/1659 [==============================] - 50s 30ms/step - loss: 0.0186 - val_loss: 0.0285
# Epoch 61/75
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0183 - val_loss: 0.0287
# Epoch 62/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0183 - val_loss: 0.0283
# Epoch 63/75
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0179 - val_loss: 0.0287
# Epoch 64/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0177 - val_loss: 0.0281
# Epoch 65/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0174 - val_loss: 0.0281
# Epoch 66/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0173 - val_loss: 0.0277
# Epoch 67/75
# 1659/1659 [==============================] - 49s 29ms/step - loss: 0.0169 - val_loss: 0.0292
# Epoch 68/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0167 - val_loss: 0.0284
# Epoch 69/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0166 - val_loss: 0.0276
# Epoch 70/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0164 - val_loss: 0.0287
# Epoch 71/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0162 - val_loss: 0.0280
# Epoch 72/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0160 - val_loss: 0.0278
# Epoch 73/75
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0158 - val_loss: 0.0283
# Epoch 74/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0156 - val_loss: 0.0277
# Epoch 75/75
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0154 - val_loss: 0.0287
# 1659/1659 [==============================] - 15s 9ms/step
# 830/830 [==============================] - 8s 9ms/step
# Average Valence MSE: 0.0270
# Average Valence MAE: 0.1257
# Average Valence RMSE: 0.1642
# Average Valence R2 Score: 0.5130
# Average Valence F1 Score: 0.8566
# Average Valence Accuracy: 0.7973
# Average Valence Precision: 0.8279
# Average Valence Recall: 0.8875
#
#
#
# Average Train MSE: 0.0175
# Average Test MSE: 0.0270
# Average Train Accuracy: 0.8383
# Average Test Accuracy: 0.7973
