# %%
import pandas as pd
import numpy as np
import glob
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, f1_score, accuracy_score, precision_score, recall_score
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'

# Get a list of all feature file paths in the directory
feature_files = glob.glob(directory_path + '/*.csv')

# Define lists to store the feature and target data
X = []
y_a = []
y_v = []

# Iterate over each feature file
for file in feature_files:
    # Read the feature file into a DataFrame
    df = pd.read_csv(file)

    # Extract the features and target variables
    features = df.drop(['Arousal_Value', 'Valence_Value', 'frameTime'], axis=1).values
    arousal = df['Arousal_Value'].values
    valence = df['Valence_Value'].values

    # Append the data to the lists
    X.append(features)
    y_a.append(arousal)
    y_v.append(valence)

# Concatenate the feature and target arrays
X = np.concatenate(X)
y_a = np.concatenate(y_a)
y_v = np.concatenate(y_v)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape the input data for LSTM
X_reshaped = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

# Define the number of folds for cross-validation
num_folds = 2

# Initialize lists to store evaluation results
mse_v = []
mae_v = []
rmse_v = []
r2_v = []
f1_v = []
accuracy_v = []
precision_v = []
recall_v = []
train_mse_v = []
test_mse_v = []
train_accuracy_v = []
test_accuracy_v = []

# Perform tenfold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(X_reshaped):
    X_train, X_val = X_reshaped[train_index], X_reshaped[test_index]
    y_v_train, y_v_val = y_v[train_index], y_v[test_index]

    # Split the validation set further into val and test sets
    val_size = len(X_val) // 2
    X_val, X_test = X_val[:val_size], X_val[val_size:]
    y_v_val, y_v_test = y_v_val[:val_size], y_v_val[val_size:]

    # Build the BiLSTM model for Arousal
    model_v = Sequential()
    model_v.add(Bidirectional(CuDNNLSTM(64, return_sequences=True), input_shape=(X_train.shape[1], 1)))
    model_v.add(Flatten())

    # Add DNN layers with dropout
    dnn_layers = [512, 256, 128, 64]  # Modify this list as needed

    for layer_size in dnn_layers:
        model_v.add(Dense(layer_size, activation='relu'))

    model_v.add(Dense(1))
    model_v.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

    # Train the Arousal model
    model_v.fit(X_train, y_v_train, validation_data=(X_val, y_v_val), epochs=50, batch_size=32)
    threshold = 0
    # Evaluate the model on the training set
    train_predictions_v = model_v.predict(X_train)
    train_mse = mean_squared_error(y_v_train, train_predictions_v)
    train_accuracy = accuracy_score(y_v_train >= threshold, train_predictions_v >= threshold)
    train_mse_v.append(train_mse)
    train_accuracy_v.append(train_accuracy)

    # Evaluate the model on the test set
    test_predictions_v = model_v.predict(X_test)
    test_mse = mean_squared_error(y_v_test, test_predictions_v)
    test_accuracy = accuracy_score(y_v_test >= threshold, test_predictions_v >= threshold)
    test_mse_v.append(test_mse)
    test_accuracy_v.append(test_accuracy)

    # Calculate additional evaluation metrics
    mae_v.append(mean_absolute_error(y_v_test, test_predictions_v))
    rmse_v.append(np.sqrt(test_mse))
    r2_v.append(r2_score(y_v_test, test_predictions_v))

    # Convert regression predictions to binary labels

    binary_predictions_v = (test_predictions_v >= threshold).astype(int)
    y_v_test_binary = (y_v_test >= threshold).astype(int)

    # Calculate F1-score, accuracy, precision, and recall for binary classification
    f1_v.append(f1_score(y_v_test_binary, binary_predictions_v))
    accuracy_v.append(accuracy_score(y_v_test_binary, binary_predictions_v))
    precision_v.append(precision_score(y_v_test_binary, binary_predictions_v))
    recall_v.append(recall_score(y_v_test_binary, binary_predictions_v))

# Calculate average performance across all folds
average_mse_v = np.mean(test_mse_v)
average_mae_v = np.mean(mae_v)
average_rmse_v = np.mean(rmse_v)
average_r2_v = np.mean(r2_v)
average_f1_v = np.mean(f1_v)
average_accuracy_v = np.mean(accuracy_v)
average_precision_v = np.mean(precision_v)
average_recall_v = np.mean(recall_v)

# Calculate average training and test MSE and accuracy across all folds
average_train_mse_v = np.mean(train_mse_v)
average_test_mse_v = np.mean(test_mse_v)
average_train_accuracy_v = np.mean(train_accuracy_v)
average_test_accuracy_v = np.mean(test_accuracy_v)

print(f'Average Valence MSE: {average_mse_v:.4f}')
print(f'Average Valence MAE: {average_mae_v:.4f}')
print(f'Average Valence RMSE: {average_rmse_v:.4f}')
print(f'Average Valence R2 Score: {average_r2_v:.4f}')
print(f'Average Valence F1 Score: {average_f1_v:.4f}')
print(f'Average Valence Accuracy: {average_accuracy_v:.4f}')
print(f'Average Valence Precision: {average_precision_v:.4f}')
print(f'Average Valence Recall: {average_recall_v:.4f}')

print("\n\n")

# Print average training and test MSE and accuracy
print(f'Average Train MSE: {average_train_mse_v:.4f}')
print(f'Average Test MSE: {average_test_mse_v:.4f}')
print(f'Average Train Accuracy: {average_train_accuracy_v:.4f}')
print(f'Average Test Accuracy: {average_test_accuracy_v:.4f}')
# Out:
# Mounted at /content/drive
# Epoch 1/50
# 1659/1659 [==============================] - 52s 25ms/step - loss: 0.0448 - val_loss: 0.0491
# Epoch 2/50
# 1659/1659 [==============================] - 42s 26ms/step - loss: 0.0404 - val_loss: 0.0416
# Epoch 3/50
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0389 - val_loss: 0.0404
# Epoch 4/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0381 - val_loss: 0.0403
# Epoch 5/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0371 - val_loss: 0.0399
# Epoch 6/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0364 - val_loss: 0.0401
# Epoch 7/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0359 - val_loss: 0.0374
# Epoch 8/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0353 - val_loss: 0.0378
# Epoch 9/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0347 - val_loss: 0.0375
# Epoch 10/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0341 - val_loss: 0.0371
# Epoch 11/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0337 - val_loss: 0.0363
# Epoch 12/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0330 - val_loss: 0.0364
# Epoch 13/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0326 - val_loss: 0.0363
# Epoch 14/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0321 - val_loss: 0.0355
# Epoch 15/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0315 - val_loss: 0.0345
# Epoch 16/50
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0312 - val_loss: 0.0339
# Epoch 17/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0307 - val_loss: 0.0337
# Epoch 18/50
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0304 - val_loss: 0.0335
# Epoch 19/50
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0299 - val_loss: 0.0340
# Epoch 20/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0296 - val_loss: 0.0323
# Epoch 21/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0289 - val_loss: 0.0330
# Epoch 22/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0287 - val_loss: 0.0329
# Epoch 23/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0283 - val_loss: 0.0321
# Epoch 24/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0280 - val_loss: 0.0333
# Epoch 25/50
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0275 - val_loss: 0.0320
# Epoch 26/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0270 - val_loss: 0.0314
# Epoch 27/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0266 - val_loss: 0.0317
# Epoch 28/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0263 - val_loss: 0.0318
# Epoch 29/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0259 - val_loss: 0.0307
# Epoch 30/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0253 - val_loss: 0.0312
# Epoch 31/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0250 - val_loss: 0.0306
# Epoch 32/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0246 - val_loss: 0.0298
# Epoch 33/50
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0242 - val_loss: 0.0297
# Epoch 34/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0239 - val_loss: 0.0297
# Epoch 35/50
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0235 - val_loss: 0.0294
# Epoch 36/50
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0232 - val_loss: 0.0300
# Epoch 37/50
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0227 - val_loss: 0.0282
# Epoch 38/50
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0225 - val_loss: 0.0284
# Epoch 39/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0221 - val_loss: 0.0295
# Epoch 40/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0217 - val_loss: 0.0280
# Epoch 41/50
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0215 - val_loss: 0.0284
# Epoch 42/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0212 - val_loss: 0.0280
# Epoch 43/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0208 - val_loss: 0.0288
# Epoch 44/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0205 - val_loss: 0.0275
# Epoch 45/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0202 - val_loss: 0.0285
# Epoch 46/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0198 - val_loss: 0.0282
# Epoch 47/50
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0198 - val_loss: 0.0281
# Epoch 48/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0193 - val_loss: 0.0284
# Epoch 49/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0190 - val_loss: 0.0278
# Epoch 50/50
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0188 - val_loss: 0.0274
# 1659/1659 [==============================] - 13s 8ms/step
# 830/830 [==============================] - 7s 9ms/step
# Epoch 1/50
# 1659/1659 [==============================] - 44s 25ms/step - loss: 0.0449 - val_loss: 0.0461
# Epoch 2/50
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0402 - val_loss: 0.0424
# Epoch 3/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0387 - val_loss: 0.0431
# Epoch 4/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0379 - val_loss: 0.0405
# Epoch 5/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0372 - val_loss: 0.0431
# Epoch 6/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0364 - val_loss: 0.0389
# Epoch 7/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0359 - val_loss: 0.0392
# Epoch 8/50
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0355 - val_loss: 0.0380
# Epoch 9/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0350 - val_loss: 0.0415
# Epoch 10/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0346 - val_loss: 0.0392
# Epoch 11/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0343 - val_loss: 0.0373
# Epoch 12/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0341 - val_loss: 0.0374
# Epoch 13/50
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0337 - val_loss: 0.0375
# Epoch 14/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0335 - val_loss: 0.0369
# Epoch 15/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0332 - val_loss: 0.0363
# Epoch 16/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0327 - val_loss: 0.0369
# Epoch 17/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0325 - val_loss: 0.0353
# Epoch 18/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0321 - val_loss: 0.0361
# Epoch 19/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0319 - val_loss: 0.0358
# Epoch 20/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0316 - val_loss: 0.0352
# Epoch 21/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0311 - val_loss: 0.0344
# Epoch 22/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0308 - val_loss: 0.0349
# Epoch 23/50
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0304 - val_loss: 0.0340
# Epoch 24/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0303 - val_loss: 0.0345
# Epoch 25/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0299 - val_loss: 0.0344
# Epoch 26/50
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0296 - val_loss: 0.0343
# Epoch 27/50
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0293 - val_loss: 0.0328
# Epoch 28/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0289 - val_loss: 0.0336
# Epoch 29/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0287 - val_loss: 0.0337
# Epoch 30/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0283 - val_loss: 0.0332
# Epoch 31/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0281 - val_loss: 0.0320
# Epoch 32/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0277 - val_loss: 0.0326
# Epoch 33/50
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0275 - val_loss: 0.0325
# Epoch 34/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0273 - val_loss: 0.0315
# Epoch 35/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0269 - val_loss: 0.0311
# Epoch 36/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0267 - val_loss: 0.0314
# Epoch 37/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0263 - val_loss: 0.0312
# Epoch 38/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0260 - val_loss: 0.0313
# Epoch 39/50
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0257 - val_loss: 0.0309
# Epoch 40/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0255 - val_loss: 0.0330
# Epoch 41/50
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0252 - val_loss: 0.0324
# Epoch 42/50
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0250 - val_loss: 0.0306
# Epoch 43/50
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0246 - val_loss: 0.0306
# Epoch 44/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0245 - val_loss: 0.0321
# Epoch 45/50
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0241 - val_loss: 0.0301
# Epoch 46/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0239 - val_loss: 0.0308
# Epoch 47/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0238 - val_loss: 0.0299
# Epoch 48/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0234 - val_loss: 0.0323
# Epoch 49/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0233 - val_loss: 0.0304
# Epoch 50/50
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0230 - val_loss: 0.0301
# 1659/1659 [==============================] - 13s 8ms/step
# 830/830 [==============================] - 6s 7ms/step
# Average Valence MSE: 0.0265
# Average Valence MAE: 0.1262
# Average Valence RMSE: 0.1627
# Average Valence R2 Score: 0.5218
# Average Valence F1 Score: 0.8538
# Average Valence Accuracy: 0.7964
# Average Valence Precision: 0.8367
# Average Valence Recall: 0.8718
#
#
#
# Average Train MSE: 0.0201
# Average Test MSE: 0.0265
# Average Train Accuracy: 0.8224
# Average Test Accuracy: 0.7964
