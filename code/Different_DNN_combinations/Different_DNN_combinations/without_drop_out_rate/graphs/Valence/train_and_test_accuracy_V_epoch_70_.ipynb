# %%
import pandas as pd
import numpy as np
import glob
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, f1_score, accuracy_score, precision_score, recall_score
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'

# Get a list of all feature file paths in the directory
feature_files = glob.glob(directory_path + '/*.csv')

# Define lists to store the feature and target data
X = []
y_a = []
y_v = []

# Iterate over each feature file
for file in feature_files:
    # Read the feature file into a DataFrame
    df = pd.read_csv(file)

    # Extract the features and target variables
    features = df.drop(['Arousal_Value', 'Valence_Value', 'frameTime'], axis=1).values
    arousal = df['Arousal_Value'].values
    valence = df['Valence_Value'].values

    # Append the data to the lists
    X.append(features)
    y_a.append(arousal)
    y_v.append(valence)

# Concatenate the feature and target arrays
X = np.concatenate(X)
y_a = np.concatenate(y_a)
y_v = np.concatenate(y_v)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape the input data for LSTM
X_reshaped = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

# Define the number of folds for cross-validation
num_folds = 2

# Initialize lists to store evaluation results
mse_v = []
mae_v = []
rmse_v = []
r2_v = []
f1_v = []
accuracy_v = []
precision_v = []
recall_v = []
train_mse_v = []
test_mse_v = []
train_accuracy_v = []
test_accuracy_v = []

# Perform tenfold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(X_reshaped):
    X_train, X_val = X_reshaped[train_index], X_reshaped[test_index]
    y_v_train, y_v_val = y_v[train_index], y_v[test_index]

    # Split the validation set further into val and test sets
    val_size = len(X_val) // 2
    X_val, X_test = X_val[:val_size], X_val[val_size:]
    y_v_val, y_v_test = y_v_val[:val_size], y_v_val[val_size:]

    # Build the BiLSTM model for Arousal
    model_v = Sequential()
    model_v.add(Bidirectional(CuDNNLSTM(64, return_sequences=True), input_shape=(X_train.shape[1], 1)))
    model_v.add(Flatten())

    # Add DNN layers with dropout
    dnn_layers = [512, 256, 128, 64]  # Modify this list as needed

    for layer_size in dnn_layers:
        model_v.add(Dense(layer_size, activation='relu'))

    model_v.add(Dense(1))
    model_v.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

    # Train the Arousal model
    model_v.fit(X_train, y_v_train, validation_data=(X_val, y_v_val), epochs=70, batch_size=32)
    threshold = 0
    # Evaluate the model on the training set
    train_predictions_v = model_v.predict(X_train)
    train_mse = mean_squared_error(y_v_train, train_predictions_v)
    train_accuracy = accuracy_score(y_v_train >= threshold, train_predictions_v >= threshold)
    train_mse_v.append(train_mse)
    train_accuracy_v.append(train_accuracy)

    # Evaluate the model on the test set
    test_predictions_v = model_v.predict(X_test)
    test_mse = mean_squared_error(y_v_test, test_predictions_v)
    test_accuracy = accuracy_score(y_v_test >= threshold, test_predictions_v >= threshold)
    test_mse_v.append(test_mse)
    test_accuracy_v.append(test_accuracy)

    # Calculate additional evaluation metrics
    mae_v.append(mean_absolute_error(y_v_test, test_predictions_v))
    rmse_v.append(np.sqrt(test_mse))
    r2_v.append(r2_score(y_v_test, test_predictions_v))

    # Convert regression predictions to binary labels

    binary_predictions_v = (test_predictions_v >= threshold).astype(int)
    y_v_test_binary = (y_v_test >= threshold).astype(int)

    # Calculate F1-score, accuracy, precision, and recall for binary classification
    f1_v.append(f1_score(y_v_test_binary, binary_predictions_v))
    accuracy_v.append(accuracy_score(y_v_test_binary, binary_predictions_v))
    precision_v.append(precision_score(y_v_test_binary, binary_predictions_v))
    recall_v.append(recall_score(y_v_test_binary, binary_predictions_v))

# Calculate average performance across all folds
average_mse_v = np.mean(test_mse_v)
average_mae_v = np.mean(mae_v)
average_rmse_v = np.mean(rmse_v)
average_r2_v = np.mean(r2_v)
average_f1_v = np.mean(f1_v)
average_accuracy_v = np.mean(accuracy_v)
average_precision_v = np.mean(precision_v)
average_recall_v = np.mean(recall_v)

# Calculate average training and test MSE and accuracy across all folds
average_train_mse_v = np.mean(train_mse_v)
average_test_mse_v = np.mean(test_mse_v)
average_train_accuracy_v = np.mean(train_accuracy_v)
average_test_accuracy_v = np.mean(test_accuracy_v)

print(f'Average Valence MSE: {average_mse_v:.4f}')
print(f'Average Valence MAE: {average_mae_v:.4f}')
print(f'Average Valence RMSE: {average_rmse_v:.4f}')
print(f'Average Valence R2 Score: {average_r2_v:.4f}')
print(f'Average Valence F1 Score: {average_f1_v:.4f}')
print(f'Average Valence Accuracy: {average_accuracy_v:.4f}')
print(f'Average Valence Precision: {average_precision_v:.4f}')
print(f'Average Valence Recall: {average_recall_v:.4f}')

print("\n\n")

# Print average training and test MSE and accuracy
print(f'Average Train MSE: {average_train_mse_v:.4f}')
print(f'Average Test MSE: {average_test_mse_v:.4f}')
print(f'Average Train Accuracy: {average_train_accuracy_v:.4f}')
print(f'Average Test Accuracy: {average_test_accuracy_v:.4f}')
# Out:
# Mounted at /content/drive
# Epoch 1/70
# 1659/1659 [==============================] - 53s 26ms/step - loss: 0.0452 - val_loss: 0.0436
# Epoch 2/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0405 - val_loss: 0.0415
# Epoch 3/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0389 - val_loss: 0.0412
# Epoch 4/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0381 - val_loss: 0.0401
# Epoch 5/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0372 - val_loss: 0.0399
# Epoch 6/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0367 - val_loss: 0.0387
# Epoch 7/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0361 - val_loss: 0.0393
# Epoch 8/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0356 - val_loss: 0.0375
# Epoch 9/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0350 - val_loss: 0.0381
# Epoch 10/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0345 - val_loss: 0.0370
# Epoch 11/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0342 - val_loss: 0.0371
# Epoch 12/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0339 - val_loss: 0.0368
# Epoch 13/70
# 1659/1659 [==============================] - 46s 27ms/step - loss: 0.0333 - val_loss: 0.0359
# Epoch 14/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0330 - val_loss: 0.0353
# Epoch 15/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0326 - val_loss: 0.0355
# Epoch 16/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0322 - val_loss: 0.0354
# Epoch 17/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0319 - val_loss: 0.0352
# Epoch 18/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0316 - val_loss: 0.0343
# Epoch 19/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0314 - val_loss: 0.0344
# Epoch 20/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0309 - val_loss: 0.0339
# Epoch 21/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0307 - val_loss: 0.0352
# Epoch 22/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0304 - val_loss: 0.0353
# Epoch 23/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0302 - val_loss: 0.0336
# Epoch 24/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0298 - val_loss: 0.0345
# Epoch 25/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0296 - val_loss: 0.0338
# Epoch 26/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0291 - val_loss: 0.0332
# Epoch 27/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0288 - val_loss: 0.0328
# Epoch 28/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0285 - val_loss: 0.0325
# Epoch 29/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0280 - val_loss: 0.0339
# Epoch 30/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0276 - val_loss: 0.0336
# Epoch 31/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0274 - val_loss: 0.0325
# Epoch 32/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0271 - val_loss: 0.0338
# Epoch 33/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0266 - val_loss: 0.0315
# Epoch 34/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0263 - val_loss: 0.0323
# Epoch 35/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0261 - val_loss: 0.0315
# Epoch 36/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0257 - val_loss: 0.0309
# Epoch 37/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0253 - val_loss: 0.0306
# Epoch 38/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0250 - val_loss: 0.0307
# Epoch 39/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0248 - val_loss: 0.0307
# Epoch 40/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0245 - val_loss: 0.0303
# Epoch 41/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0242 - val_loss: 0.0300
# Epoch 42/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0239 - val_loss: 0.0308
# Epoch 43/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0236 - val_loss: 0.0303
# Epoch 44/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0231 - val_loss: 0.0306
# Epoch 45/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0229 - val_loss: 0.0309
# Epoch 46/70
# 1659/1659 [==============================] - 46s 27ms/step - loss: 0.0226 - val_loss: 0.0304
# Epoch 47/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0223 - val_loss: 0.0303
# Epoch 48/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0222 - val_loss: 0.0292
# Epoch 49/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0218 - val_loss: 0.0293
# Epoch 50/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0214 - val_loss: 0.0297
# Epoch 51/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0214 - val_loss: 0.0293
# Epoch 52/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0211 - val_loss: 0.0293
# Epoch 53/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0209 - val_loss: 0.0291
# Epoch 54/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0204 - val_loss: 0.0289
# Epoch 55/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0203 - val_loss: 0.0287
# Epoch 56/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0200 - val_loss: 0.0286
# Epoch 57/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0199 - val_loss: 0.0292
# Epoch 58/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0195 - val_loss: 0.0294
# Epoch 59/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0192 - val_loss: 0.0286
# Epoch 60/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0191 - val_loss: 0.0299
# Epoch 61/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0188 - val_loss: 0.0286
# Epoch 62/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0186 - val_loss: 0.0287
# Epoch 63/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0183 - val_loss: 0.0299
# Epoch 64/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0182 - val_loss: 0.0305
# Epoch 65/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0178 - val_loss: 0.0281
# Epoch 66/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0177 - val_loss: 0.0280
# Epoch 67/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0174 - val_loss: 0.0286
# Epoch 68/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0172 - val_loss: 0.0290
# Epoch 69/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0170 - val_loss: 0.0286
# Epoch 70/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0169 - val_loss: 0.0283
# 1659/1659 [==============================] - 13s 8ms/step
# 830/830 [==============================] - 7s 8ms/step
# Epoch 1/70
# 1659/1659 [==============================] - 44s 25ms/step - loss: 0.0444 - val_loss: 0.0440
# Epoch 2/70
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0402 - val_loss: 0.0440
# Epoch 3/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0388 - val_loss: 0.0411
# Epoch 4/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0378 - val_loss: 0.0397
# Epoch 5/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0368 - val_loss: 0.0417
# Epoch 6/70
# 1659/1659 [==============================] - 44s 26ms/step - loss: 0.0362 - val_loss: 0.0389
# Epoch 7/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0357 - val_loss: 0.0377
# Epoch 8/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0350 - val_loss: 0.0376
# Epoch 9/70
# 1659/1659 [==============================] - 42s 26ms/step - loss: 0.0343 - val_loss: 0.0368
# Epoch 10/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0338 - val_loss: 0.0368
# Epoch 11/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0334 - val_loss: 0.0361
# Epoch 12/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0331 - val_loss: 0.0359
# Epoch 13/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0327 - val_loss: 0.0360
# Epoch 14/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0324 - val_loss: 0.0354
# Epoch 15/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0318 - val_loss: 0.0354
# Epoch 16/70
# 1659/1659 [==============================] - 42s 26ms/step - loss: 0.0315 - val_loss: 0.0351
# Epoch 17/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0310 - val_loss: 0.0341
# Epoch 18/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0307 - val_loss: 0.0344
# Epoch 19/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0302 - val_loss: 0.0339
# Epoch 20/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0299 - val_loss: 0.0330
# Epoch 21/70
# 1659/1659 [==============================] - 44s 26ms/step - loss: 0.0295 - val_loss: 0.0343
# Epoch 22/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0291 - val_loss: 0.0335
# Epoch 23/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0287 - val_loss: 0.0320
# Epoch 24/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0284 - val_loss: 0.0328
# Epoch 25/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0280 - val_loss: 0.0320
# Epoch 26/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0275 - val_loss: 0.0312
# Epoch 27/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0272 - val_loss: 0.0313
# Epoch 28/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0268 - val_loss: 0.0315
# Epoch 29/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0266 - val_loss: 0.0314
# Epoch 30/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0262 - val_loss: 0.0317
# Epoch 31/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0259 - val_loss: 0.0305
# Epoch 32/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0254 - val_loss: 0.0310
# Epoch 33/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0252 - val_loss: 0.0305
# Epoch 34/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0249 - val_loss: 0.0302
# Epoch 35/70
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0246 - val_loss: 0.0293
# Epoch 36/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0241 - val_loss: 0.0301
# Epoch 37/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0241 - val_loss: 0.0319
# Epoch 38/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0237 - val_loss: 0.0303
# Epoch 39/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0233 - val_loss: 0.0300
# Epoch 40/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0231 - val_loss: 0.0290
# Epoch 41/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0228 - val_loss: 0.0299
# Epoch 42/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0226 - val_loss: 0.0290
# Epoch 43/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0223 - val_loss: 0.0287
# Epoch 44/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0218 - val_loss: 0.0289
# Epoch 45/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0217 - val_loss: 0.0290
# Epoch 46/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0214 - val_loss: 0.0284
# Epoch 47/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0212 - val_loss: 0.0297
# Epoch 48/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0210 - val_loss: 0.0291
# Epoch 49/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0208 - val_loss: 0.0284
# Epoch 50/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0205 - val_loss: 0.0308
# Epoch 51/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0202 - val_loss: 0.0289
# Epoch 52/70
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0200 - val_loss: 0.0289
# Epoch 53/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0198 - val_loss: 0.0290
# Epoch 54/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0196 - val_loss: 0.0289
# Epoch 55/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0194 - val_loss: 0.0286
# Epoch 56/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0190 - val_loss: 0.0282
# Epoch 57/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0189 - val_loss: 0.0285
# Epoch 58/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0187 - val_loss: 0.0289
# Epoch 59/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0185 - val_loss: 0.0284
# Epoch 60/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0182 - val_loss: 0.0288
# Epoch 61/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0180 - val_loss: 0.0285
# Epoch 62/70
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0178 - val_loss: 0.0284
# Epoch 63/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0178 - val_loss: 0.0282
# Epoch 64/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0174 - val_loss: 0.0273
# Epoch 65/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0172 - val_loss: 0.0284
# Epoch 66/70
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0170 - val_loss: 0.0280
# Epoch 67/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0170 - val_loss: 0.0282
# Epoch 68/70
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0168 - val_loss: 0.0273
# Epoch 69/70
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0165 - val_loss: 0.0280
# Epoch 70/70
# 1659/1659 [==============================] - 42s 26ms/step - loss: 0.0164 - val_loss: 0.0288
# 1659/1659 [==============================] - 14s 8ms/step
# 830/830 [==============================] - 7s 9ms/step
# Average Valence MSE: 0.0261
# Average Valence MAE: 0.1241
# Average Valence RMSE: 0.1616
# Average Valence R2 Score: 0.5281
# Average Valence F1 Score: 0.8544
# Average Valence Accuracy: 0.7973
# Average Valence Precision: 0.8376
# Average Valence Recall: 0.8719
#
#
#
# Average Train MSE: 0.0163
# Average Test MSE: 0.0261
# Average Train Accuracy: 0.8462
# Average Test Accuracy: 0.7973
