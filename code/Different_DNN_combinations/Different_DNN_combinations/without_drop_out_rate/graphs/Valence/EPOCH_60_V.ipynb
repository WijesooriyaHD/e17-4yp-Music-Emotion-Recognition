# %%
import pandas as pd
import numpy as np
import glob
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, f1_score, accuracy_score, precision_score, recall_score
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'

# Get a list of all feature file paths in the directory
feature_files = glob.glob(directory_path + '/*.csv')

# Define lists to store the feature and target data
X = []
y_a = []
y_v = []

# Iterate over each feature file
for file in feature_files:
    # Read the feature file into a DataFrame
    df = pd.read_csv(file)

    # Extract the features and target variables
    features = df.drop(['Arousal_Value', 'Valence_Value', 'frameTime'], axis=1).values
    arousal = df['Arousal_Value'].values
    valence = df['Valence_Value'].values

    # Append the data to the lists
    X.append(features)
    y_a.append(arousal)
    y_v.append(valence)

# Concatenate the feature and target arrays
X = np.concatenate(X)
y_a = np.concatenate(y_a)
y_v = np.concatenate(y_v)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape the input data for LSTM
X_reshaped = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

# Define the number of folds for cross-validation
num_folds = 2

# Initialize lists to store evaluation results
mse_v = []
mae_v = []
rmse_v = []
r2_v = []
f1_v = []
accuracy_v = []
precision_v = []
recall_v = []
train_mse_v = []
test_mse_v = []
train_accuracy_v = []
test_accuracy_v = []

# Perform tenfold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(X_reshaped):
    X_train, X_val = X_reshaped[train_index], X_reshaped[test_index]
    y_v_train, y_v_val = y_v[train_index], y_v[test_index]

    # Split the validation set further into val and test sets
    val_size = len(X_val) // 2
    X_val, X_test = X_val[:val_size], X_val[val_size:]
    y_v_val, y_v_test = y_v_val[:val_size], y_v_val[val_size:]

    # Build the BiLSTM model for Arousal
    model_v = Sequential()
    model_v.add(Bidirectional(CuDNNLSTM(64, return_sequences=True), input_shape=(X_train.shape[1], 1)))
    model_v.add(Flatten())

    # Add DNN layers with dropout
    dnn_layers = [512, 256, 128, 64]  # Modify this list as needed

    for layer_size in dnn_layers:
        model_v.add(Dense(layer_size, activation='relu'))

    model_v.add(Dense(1))
    model_v.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

    # Train the Arousal model
    model_v.fit(X_train, y_v_train, validation_data=(X_val, y_v_val), epochs=60, batch_size=32)
    threshold = 0
    # Evaluate the model on the training set
    train_predictions_v = model_v.predict(X_train)
    train_mse = mean_squared_error(y_v_train, train_predictions_v)
    train_accuracy = accuracy_score(y_v_train >= threshold, train_predictions_v >= threshold)
    train_mse_v.append(train_mse)
    train_accuracy_v.append(train_accuracy)

    # Evaluate the model on the test set
    test_predictions_v = model_v.predict(X_test)
    test_mse = mean_squared_error(y_v_test, test_predictions_v)
    test_accuracy = accuracy_score(y_v_test >= threshold, test_predictions_v >= threshold)
    test_mse_v.append(test_mse)
    test_accuracy_v.append(test_accuracy)

    # Calculate additional evaluation metrics
    mae_v.append(mean_absolute_error(y_v_test, test_predictions_v))
    rmse_v.append(np.sqrt(test_mse))
    r2_v.append(r2_score(y_v_test, test_predictions_v))

    # Convert regression predictions to binary labels

    binary_predictions_v = (test_predictions_v >= threshold).astype(int)
    y_v_test_binary = (y_v_test >= threshold).astype(int)

    # Calculate F1-score, accuracy, precision, and recall for binary classification
    f1_v.append(f1_score(y_v_test_binary, binary_predictions_v))
    accuracy_v.append(accuracy_score(y_v_test_binary, binary_predictions_v))
    precision_v.append(precision_score(y_v_test_binary, binary_predictions_v))
    recall_v.append(recall_score(y_v_test_binary, binary_predictions_v))

# Calculate average performance across all folds
average_mse_v = np.mean(test_mse_v)
average_mae_v = np.mean(mae_v)
average_rmse_v = np.mean(rmse_v)
average_r2_v = np.mean(r2_v)
average_f1_v = np.mean(f1_v)
average_accuracy_v = np.mean(accuracy_v)
average_precision_v = np.mean(precision_v)
average_recall_v = np.mean(recall_v)

# Calculate average training and test MSE and accuracy across all folds
average_train_mse_v = np.mean(train_mse_v)
average_test_mse_v = np.mean(test_mse_v)
average_train_accuracy_v = np.mean(train_accuracy_v)
average_test_accuracy_v = np.mean(test_accuracy_v)

print(f'Average Valence MSE: {average_mse_v:.4f}')
print(f'Average Valence MAE: {average_mae_v:.4f}')
print(f'Average Valence RMSE: {average_rmse_v:.4f}')
print(f'Average Valence R2 Score: {average_r2_v:.4f}')
print(f'Average Valence F1 Score: {average_f1_v:.4f}')
print(f'Average Valence Accuracy: {average_accuracy_v:.4f}')
print(f'Average Valence Precision: {average_precision_v:.4f}')
print(f'Average Valence Recall: {average_recall_v:.4f}')

print("\n\n")

# Print average training and test MSE and accuracy
print(f'Average Train MSE: {average_train_mse_v:.4f}')
print(f'Average Test MSE: {average_test_mse_v:.4f}')
print(f'Average Train Accuracy: {average_train_accuracy_v:.4f}')
print(f'Average Test Accuracy: {average_test_accuracy_v:.4f}')
# Out:
# Mounted at /content/drive
# Epoch 1/60
# 1659/1659 [==============================] - 52s 25ms/step - loss: 0.0452 - val_loss: 0.0434
# Epoch 2/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0405 - val_loss: 0.0427
# Epoch 3/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0393 - val_loss: 0.0450
# Epoch 4/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0381 - val_loss: 0.0408
# Epoch 5/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0374 - val_loss: 0.0401
# Epoch 6/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0366 - val_loss: 0.0392
# Epoch 7/60
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0358 - val_loss: 0.0382
# Epoch 8/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0351 - val_loss: 0.0371
# Epoch 9/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0345 - val_loss: 0.0372
# Epoch 10/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0341 - val_loss: 0.0362
# Epoch 11/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0335 - val_loss: 0.0356
# Epoch 12/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0331 - val_loss: 0.0358
# Epoch 13/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0325 - val_loss: 0.0355
# Epoch 14/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0321 - val_loss: 0.0349
# Epoch 15/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0315 - val_loss: 0.0345
# Epoch 16/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0312 - val_loss: 0.0352
# Epoch 17/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0308 - val_loss: 0.0333
# Epoch 18/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0304 - val_loss: 0.0340
# Epoch 19/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0300 - val_loss: 0.0329
# Epoch 20/60
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0295 - val_loss: 0.0328
# Epoch 21/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0291 - val_loss: 0.0330
# Epoch 22/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0289 - val_loss: 0.0326
# Epoch 23/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0285 - val_loss: 0.0336
# Epoch 24/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0280 - val_loss: 0.0317
# Epoch 25/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0277 - val_loss: 0.0320
# Epoch 26/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0273 - val_loss: 0.0331
# Epoch 27/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0271 - val_loss: 0.0320
# Epoch 28/60
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0267 - val_loss: 0.0324
# Epoch 29/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0265 - val_loss: 0.0315
# Epoch 30/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0261 - val_loss: 0.0305
# Epoch 31/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0258 - val_loss: 0.0305
# Epoch 32/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0255 - val_loss: 0.0309
# Epoch 33/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0251 - val_loss: 0.0303
# Epoch 34/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0248 - val_loss: 0.0308
# Epoch 35/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0245 - val_loss: 0.0309
# Epoch 36/60
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0242 - val_loss: 0.0304
# Epoch 37/60
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0238 - val_loss: 0.0301
# Epoch 38/60
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0236 - val_loss: 0.0296
# Epoch 39/60
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0233 - val_loss: 0.0295
# Epoch 40/60
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0230 - val_loss: 0.0303
# Epoch 41/60
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0227 - val_loss: 0.0300
# Epoch 42/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0226 - val_loss: 0.0297
# Epoch 43/60
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0221 - val_loss: 0.0295
# Epoch 44/60
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0220 - val_loss: 0.0297
# Epoch 45/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0215 - val_loss: 0.0307
# Epoch 46/60
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0213 - val_loss: 0.0291
# Epoch 47/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0210 - val_loss: 0.0284
# Epoch 48/60
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0209 - val_loss: 0.0293
# Epoch 49/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0205 - val_loss: 0.0295
# Epoch 50/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0202 - val_loss: 0.0295
# Epoch 51/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0200 - val_loss: 0.0290
# Epoch 52/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0200 - val_loss: 0.0293
# Epoch 53/60
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0195 - val_loss: 0.0286
# Epoch 54/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0195 - val_loss: 0.0293
# Epoch 55/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0191 - val_loss: 0.0294
# Epoch 56/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0189 - val_loss: 0.0283
# Epoch 57/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0186 - val_loss: 0.0287
# Epoch 58/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0184 - val_loss: 0.0288
# Epoch 59/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0182 - val_loss: 0.0280
# Epoch 60/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0179 - val_loss: 0.0292
# 1659/1659 [==============================] - 13s 7ms/step
# 830/830 [==============================] - 6s 8ms/step
# Epoch 1/60
# 1659/1659 [==============================] - 46s 25ms/step - loss: 0.0447 - val_loss: 0.0449
# Epoch 2/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0402 - val_loss: 0.0425
# Epoch 3/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0389 - val_loss: 0.0428
# Epoch 4/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0382 - val_loss: 0.0401
# Epoch 5/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0372 - val_loss: 0.0394
# Epoch 6/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0365 - val_loss: 0.0394
# Epoch 7/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0359 - val_loss: 0.0389
# Epoch 8/60
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0353 - val_loss: 0.0385
# Epoch 9/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0350 - val_loss: 0.0391
# Epoch 10/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0345 - val_loss: 0.0401
# Epoch 11/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0339 - val_loss: 0.0367
# Epoch 12/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0337 - val_loss: 0.0381
# Epoch 13/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0333 - val_loss: 0.0360
# Epoch 14/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0329 - val_loss: 0.0386
# Epoch 15/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0326 - val_loss: 0.0357
# Epoch 16/60
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0324 - val_loss: 0.0365
# Epoch 17/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 18/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0318 - val_loss: 0.0345
# Epoch 19/60
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0314 - val_loss: 0.0353
# Epoch 20/60
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0312 - val_loss: 0.0339
# Epoch 21/60
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0309 - val_loss: 0.0359
# Epoch 22/60
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0306 - val_loss: 0.0337
# Epoch 23/60
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0303 - val_loss: 0.0341
# Epoch 24/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0301 - val_loss: 0.0338
# Epoch 25/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0297 - val_loss: 0.0333
# Epoch 26/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0295 - val_loss: 0.0338
# Epoch 27/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0292 - val_loss: 0.0339
# Epoch 28/60
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0289 - val_loss: 0.0330
# Epoch 29/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0287 - val_loss: 0.0323
# Epoch 30/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0283 - val_loss: 0.0325
# Epoch 31/60
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0281 - val_loss: 0.0327
# Epoch 32/60
# 1659/1659 [==============================] - 46s 27ms/step - loss: 0.0278 - val_loss: 0.0326
# Epoch 33/60
# 1659/1659 [==============================] - 42s 26ms/step - loss: 0.0275 - val_loss: 0.0317
# Epoch 34/60
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0273 - val_loss: 0.0319
# Epoch 35/60
# 1659/1659 [==============================] - 42s 26ms/step - loss: 0.0269 - val_loss: 0.0319
# Epoch 36/60
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0268 - val_loss: 0.0313
# Epoch 37/60
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0264 - val_loss: 0.0319
# Epoch 38/60
# 1659/1659 [==============================] - 42s 26ms/step - loss: 0.0260 - val_loss: 0.0322
# Epoch 39/60
# 1659/1659 [==============================] - 42s 26ms/step - loss: 0.0258 - val_loss: 0.0304
# Epoch 40/60
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0256 - val_loss: 0.0304
# Epoch 41/60
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0253 - val_loss: 0.0317
# Epoch 42/60
# 1659/1659 [==============================] - 49s 30ms/step - loss: 0.0250 - val_loss: 0.0301
# Epoch 43/60
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0247 - val_loss: 0.0305
# Epoch 44/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0245 - val_loss: 0.0302
# Epoch 45/60
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0241 - val_loss: 0.0308
# Epoch 46/60
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0239 - val_loss: 0.0332
# Epoch 47/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0238 - val_loss: 0.0299
# Epoch 48/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0235 - val_loss: 0.0302
# Epoch 49/60
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0231 - val_loss: 0.0302
# Epoch 50/60
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0230 - val_loss: 0.0309
# Epoch 51/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0227 - val_loss: 0.0304
# Epoch 52/60
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0225 - val_loss: 0.0299
# Epoch 53/60
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0223 - val_loss: 0.0296
# Epoch 54/60
# 1659/1659 [==============================] - 47s 28ms/step - loss: 0.0220 - val_loss: 0.0293
# Epoch 55/60
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0219 - val_loss: 0.0291
# Epoch 56/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0215 - val_loss: 0.0304
# Epoch 57/60
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0214 - val_loss: 0.0290
# Epoch 58/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0211 - val_loss: 0.0291
# Epoch 59/60
# 1659/1659 [==============================] - 48s 29ms/step - loss: 0.0210 - val_loss: 0.0291
# Epoch 60/60
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0208 - val_loss: 0.0289
# 1659/1659 [==============================] - 15s 9ms/step
# 830/830 [==============================] - 7s 8ms/step
# Average Valence MSE: 0.0265
# Average Valence MAE: 0.1263
# Average Valence RMSE: 0.1629
# Average Valence R2 Score: 0.5209
# Average Valence F1 Score: 0.8517
# Average Valence Accuracy: 0.7959
# Average Valence Precision: 0.8443
# Average Valence Recall: 0.8596
#
#
#
# Average Train MSE: 0.0186
# Average Test MSE: 0.0265
# Average Train Accuracy: 0.8320
# Average Test Accuracy: 0.7959
