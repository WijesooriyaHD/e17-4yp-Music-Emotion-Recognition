# %%
import pandas as pd
import numpy as np
import glob
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, f1_score, accuracy_score, precision_score, recall_score
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'

# Get a list of all feature file paths in the directory
feature_files = glob.glob(directory_path + '/*.csv')

# Define lists to store the feature and target data
X = []
y_a = []
y_v = []

# Iterate over each feature file
for file in feature_files:
    # Read the feature file into a DataFrame
    df = pd.read_csv(file)

    # Extract the features and target variables
    features = df.drop(['Arousal_Value', 'Valence_Value', 'frameTime'], axis=1).values
    arousal = df['Arousal_Value'].values
    valence = df['Valence_Value'].values

    # Append the data to the lists
    X.append(features)
    y_a.append(arousal)
    y_v.append(valence)

# Concatenate the feature and target arrays
X = np.concatenate(X)
y_a = np.concatenate(y_a)
y_v = np.concatenate(y_v)

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape the input data for LSTM
X_reshaped = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

# Define the number of folds for cross-validation
num_folds = 2

# Initialize lists to store evaluation results
mse_v = []
mae_v = []
rmse_v = []
r2_v = []
f1_v = []
accuracy_v = []
precision_v = []
recall_v = []
train_mse_v = []
test_mse_v = []
train_accuracy_v = []
test_accuracy_v = []

# Perform tenfold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(X_reshaped):
    X_train, X_val = X_reshaped[train_index], X_reshaped[test_index]
    y_v_train, y_v_val = y_v[train_index], y_v[test_index]

    # Split the validation set further into val and test sets
    val_size = len(X_val) // 2
    X_val, X_test = X_val[:val_size], X_val[val_size:]
    y_v_val, y_v_test = y_v_val[:val_size], y_v_val[val_size:]

    # Build the BiLSTM model for Arousal
    model_v = Sequential()
    model_v.add(Bidirectional(CuDNNLSTM(64, return_sequences=True), input_shape=(X_train.shape[1], 1)))
    model_v.add(Flatten())

    # Add DNN layers with dropout
    dnn_layers = [512, 256, 128, 64]  # Modify this list as needed

    for layer_size in dnn_layers:
        model_v.add(Dense(layer_size, activation='relu'))

    model_v.add(Dense(1))
    model_v.compile(loss='mse', optimizer=Adam(learning_rate=0.001))

    # Train the Arousal model
    model_v.fit(X_train, y_v_train, validation_data=(X_val, y_v_val), epochs=45, batch_size=32)
    threshold = 0
    # Evaluate the model on the training set
    train_predictions_v = model_v.predict(X_train)
    train_mse = mean_squared_error(y_v_train, train_predictions_v)
    train_accuracy = accuracy_score(y_v_train >= threshold, train_predictions_v >= threshold)
    train_mse_v.append(train_mse)
    train_accuracy_v.append(train_accuracy)

    # Evaluate the model on the test set
    test_predictions_v = model_v.predict(X_test)
    test_mse = mean_squared_error(y_v_test, test_predictions_v)
    test_accuracy = accuracy_score(y_v_test >= threshold, test_predictions_v >= threshold)
    test_mse_v.append(test_mse)
    test_accuracy_v.append(test_accuracy)

    # Calculate additional evaluation metrics
    mae_v.append(mean_absolute_error(y_v_test, test_predictions_v))
    rmse_v.append(np.sqrt(test_mse))
    r2_v.append(r2_score(y_v_test, test_predictions_v))

    # Convert regression predictions to binary labels

    binary_predictions_v = (test_predictions_v >= threshold).astype(int)
    y_v_test_binary = (y_v_test >= threshold).astype(int)

    # Calculate F1-score, accuracy, precision, and recall for binary classification
    f1_v.append(f1_score(y_v_test_binary, binary_predictions_v))
    accuracy_v.append(accuracy_score(y_v_test_binary, binary_predictions_v))
    precision_v.append(precision_score(y_v_test_binary, binary_predictions_v))
    recall_v.append(recall_score(y_v_test_binary, binary_predictions_v))

# Calculate average performance across all folds
average_mse_v = np.mean(test_mse_v)
average_mae_v = np.mean(mae_v)
average_rmse_v = np.mean(rmse_v)
average_r2_v = np.mean(r2_v)
average_f1_v = np.mean(f1_v)
average_accuracy_v = np.mean(accuracy_v)
average_precision_v = np.mean(precision_v)
average_recall_v = np.mean(recall_v)

# Calculate average training and test MSE and accuracy across all folds
average_train_mse_v = np.mean(train_mse_v)
average_test_mse_v = np.mean(test_mse_v)
average_train_accuracy_v = np.mean(train_accuracy_v)
average_test_accuracy_v = np.mean(test_accuracy_v)

print(f'Average Valence MSE: {average_mse_v:.4f}')
print(f'Average Valence MAE: {average_mae_v:.4f}')
print(f'Average Valence RMSE: {average_rmse_v:.4f}')
print(f'Average Valence R2 Score: {average_r2_v:.4f}')
print(f'Average Valence F1 Score: {average_f1_v:.4f}')
print(f'Average Valence Accuracy: {average_accuracy_v:.4f}')
print(f'Average Valence Precision: {average_precision_v:.4f}')
print(f'Average Valence Recall: {average_recall_v:.4f}')

print("\n\n")

# Print average training and test MSE and accuracy
print(f'Average Train MSE: {average_train_mse_v:.4f}')
print(f'Average Test MSE: {average_test_mse_v:.4f}')
print(f'Average Train Accuracy: {average_train_accuracy_v:.4f}')
print(f'Average Test Accuracy: {average_test_accuracy_v:.4f}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Epoch 1/45
# 1659/1659 [==============================] - 45s 25ms/step - loss: 0.0449 - val_loss: 0.0446
# Epoch 2/45
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0405 - val_loss: 0.0428
# Epoch 3/45
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0391 - val_loss: 0.0412
# Epoch 4/45
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0381 - val_loss: 0.0393
# Epoch 5/45
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0373 - val_loss: 0.0393
# Epoch 6/45
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0368 - val_loss: 0.0391
# Epoch 7/45
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0361 - val_loss: 0.0382
# Epoch 8/45
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0357 - val_loss: 0.0378
# Epoch 9/45
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0353 - val_loss: 0.0373
# Epoch 10/45
# 1659/1659 [==============================] - 44s 26ms/step - loss: 0.0347 - val_loss: 0.0372
# Epoch 11/45
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0345 - val_loss: 0.0366
# Epoch 12/45
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0340 - val_loss: 0.0371
# Epoch 13/45
# 1659/1659 [==============================] - 42s 26ms/step - loss: 0.0339 - val_loss: 0.0365
# Epoch 14/45
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0337 - val_loss: 0.0361
# Epoch 15/45
# 1659/1659 [==============================] - 46s 28ms/step - loss: 0.0331 - val_loss: 0.0363
# Epoch 16/45
# 1659/1659 [==============================] - 43s 26ms/step - loss: 0.0329 - val_loss: 0.0364
# Epoch 17/45
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0325 - val_loss: 0.0353
# Epoch 18/45
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0323 - val_loss: 0.0357
# Epoch 19/45
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0320 - val_loss: 0.0352
# Epoch 20/45
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0317 - val_loss: 0.0349
# Epoch 21/45
# 1659/1659 [==============================] - 46s 27ms/step - loss: 0.0314 - val_loss: 0.0360
# Epoch 22/45
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.
# 1659/1659 [==============================] - 42s 25ms/step - loss: 0.0321 - val_loss: 0.0355
# Epoch 18/45
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0318 - val_loss: 0.0348
# Epoch 19/45
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0316 - val_loss: 0.0346
# Epoch 20/45
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0312 - val_loss: 0.0341
# Epoch 21/45
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0309 - val_loss: 0.0343
# Epoch 22/45
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0305 - val_loss: 0.0334
# Epoch 23/45
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0302 - val_loss: 0.0346
# Epoch 24/45
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0299 - val_loss: 0.0333
# Epoch 25/45
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0296 - val_loss: 0.0335
# Epoch 26/45
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0293 - val_loss: 0.0338
# Epoch 27/45
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0291 - val_loss: 0.0338
# Epoch 28/45
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0287 - val_loss: 0.0327
# Epoch 29/45
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0286 - val_loss: 0.0334
# Epoch 30/45
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0283 - val_loss: 0.0321
# Epoch 31/45
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0282 - val_loss: 0.0326
# Epoch 32/45
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0277 - val_loss: 0.0331
# Epoch 33/45
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0276 - val_loss: 0.0319
# Epoch 34/45
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0272 - val_loss: 0.0322
# Epoch 35/45
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0269 - val_loss: 0.0318
# Epoch 36/45
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0267 - val_loss: 0.0321
# Epoch 37/45
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0265 - val_loss: 0.0317
# Epoch 38/45
# 1659/1659 [==============================] - 44s 27ms/step - loss: 0.0262 - val_loss: 0.0319
# Epoch 39/45
# 1659/1659 [==============================] - 41s 25ms/step - loss: 0.0259 - val_loss: 0.0321
# Epoch 40/45
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0256 - val_loss: 0.0310
# Epoch 41/45
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0253 - val_loss: 0.0314
# Epoch 42/45
# 1659/1659 [==============================] - 41s 24ms/step - loss: 0.0250 - val_loss: 0.0319
# Epoch 43/45
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0247 - val_loss: 0.0312
# Epoch 44/45
# 1659/1659 [==============================] - 40s 24ms/step - loss: 0.0245 - val_loss: 0.0309
# Epoch 45/45
# 1659/1659 [==============================] - 45s 27ms/step - loss: 0.0242 - val_loss: 0.0304
# 1659/1659 [==============================] - 13s 8ms/step
# 830/830 [==============================] - 6s 8ms/step
# Average Valence MSE: 0.0275
# Average Valence MAE: 0.1297
# Average Valence RMSE: 0.1658
# Average Valence R2 Score: 0.5034
# Average Valence F1 Score: 0.8514
# Average Valence Accuracy: 0.7919
# Average Valence Precision: 0.8299
# Average Valence Recall: 0.8742
#
#
#
# Average Train MSE: 0.0238
# Average Test MSE: 0.0275
# Average Train Accuracy: 0.8004
# Average Test Accuracy: 0.7919
