# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1) .csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['Accuracy - V'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(6, 6))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(75,81 )  # Adjust the limits as needed

bars = plt.bar(dnn_configurations, accuracies, color='skyblue')
plt.xlabel('DNN Configuration')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy for Different DNN Configurations')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability

# Annotate the bars with their accuracy values at the top
for bar, acc in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2, acc + 0.1, f'{acc}%', ha='center', va='bottom', fontsize=9)

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('accuracy_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1) .csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['Accuracy - V'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Add MSE values
mse_values = df['RMSE - V']*100  # Assuming the column name is 'MSE - V'
mse_values = mse_values.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(0, 100)  # Adjust the limits as needed

# Create bars for accuracy and MSE
bar_width = 0.35
index = np.arange(len(dnn_configurations))
plt.bar(index, accuracies, bar_width, label='Accuracy', color='skyblue', align='center')
plt.bar(index + bar_width, mse_values, bar_width, label='MSE', color='lightcoral', alpha=0.7, align='center')

plt.xlabel('DNN Configuration')
plt.ylabel('Values')
plt.title('Accuracy and RMSE for Different DNN Configurations')
plt.xticks(index + bar_width/2, dnn_configurations, rotation=90)  # Rotate x-axis labels for readability
plt.legend()

# Annotate the bars with their accuracy and MSE values at the top
for i, (acc, mse) in enumerate(zip(accuracies, mse_values)):
    plt.text(index[i] + bar_width/2, acc + 2, f'{acc}%', ha='center', va='bottom', fontsize=9)
    plt.text(index[i] + bar_width/2, mse + 2, f'{mse}', ha='center', va='bottom', fontsize=9)


# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('accuracy_mse_plot.png')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1) .csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['MSE - V'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(6, 6))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(0,4 )  # Adjust the limits as needed

bars = plt.bar(dnn_configurations, accuracies, color='lightcoral')
plt.xlabel('DNN Configuration')
plt.ylabel('MSE  (%)')
plt.title('MSE for Different DNN Configurations')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability

# Annotate the bars with their accuracy values at the top
for bar, acc in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2, acc + 0.1, f'{acc}%', ha='center', va='bottom', fontsize=9)

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('accuracy_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1) .csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)

# Extract the metrics you want to display
metrics = ['R2 Score - V', 'F1 Score - V', 'Accuracy - V', 'Precision - V', 'Recall - V']

# Create a line plot
plt.figure(figsize=(12, 10))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(40, 100)  # Adjust the limits as needed

# Plot each metric as a line
for metric in metrics:
    values = df[metric] * 100
    values = values.round(2)
    plt.plot(dnn_configurations, values, marker='o', label=metric)

plt.xlabel('DNN Configuration')
plt.ylabel('Values')
plt.title('Performance Metrics for Different DNN Configurations')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.legend()

# Annotate the data points with their values
for metric in metrics:
    values = df[metric] * 100
    values = values.round(2)
    for i, value in enumerate(values):
        plt.annotate(f'{value}', (i, value + 2), textcoords="offset points", xytext=(0, 10), ha='center')

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('metrics_line_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/DNN results different layers - v - Sheet1.csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)

# Extract the metrics you want to display
metrics = [ 'R2 Score - V', 'F1 Score - V', 'Accuracy - V', 'Precision - V', 'Recall - V']

# Create a line plot
plt.figure(figsize=(12, 10))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(40, 95)  # Adjust the limits as needed

# Plot each metric as a line
for metric in metrics:
    values = df[metric] * 100
    values = values.round(2)
    plt.plot(dnn_configurations, values, marker='o', label=metric)

plt.xlabel('DNN Configuration')
plt.ylabel('Values')
plt.title('Performance Metrics for Different DNN Configurations')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.legend()

# Annotate the data points with their values
for metric in metrics:
    values = df[metric] * 100
    values = values.round(2)
    for i, value in enumerate(values):
        plt.annotate(f'{value}', (i, value), textcoords="offset points", xytext=(0, 10), ha='center')

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('metrics_line_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/DNN results different layers - v - Sheet1.csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)

# Extract the metrics you want to display
metrics = ['R2 Score - V', 'F1 Score - V', 'Accuracy - V', 'Precision - V', 'Recall - V']

# Create a line plot
plt.figure(figsize=(12, 10))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(40, 95)  # Adjust the limits as needed

# Plot each metric as a line
for metric in metrics:
    values = df[metric] * 100
    values = values.round(2)
    plt.plot(dnn_configurations, values, marker='o', label=metric)

plt.xlabel('DNN Configuration')
plt.ylabel('Values')
plt.title('Performance Metrics for Different DNN Configurations')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.legend()

# Annotate the data points with their values
for metric in metrics:
    values = df[metric] * 100
    values = values.round(2)
    for i, value in enumerate(values):
        plt.annotate(f'{value}', (i, value), textcoords="offset points", xytext=(0, 5), ha='center')

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('metrics_line_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1) .csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['Accuracy - V'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Add MSE values
mse_values = df['MSE - V']*100  # Assuming the column name is 'MSE - V'
mse_values = mse_values.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(0, 100)  # Adjust the limits as needed

# Create bars for accuracy and MSE
bar_width = 0.3
index = np.arange(len(dnn_configurations))
plt.bar(index, accuracies, bar_width, label='Accuracy', color='skyblue', align='center')
plt.bar(index + bar_width, mse_values, bar_width, label='MSE', color='lightcoral', alpha=0.7, align='center')

plt.xlabel('DNN Configuration')
plt.ylabel('Values')
plt.title('Accuracy and MSE for Different DNN Configurations')
plt.xticks(index + bar_width/2, dnn_configurations, rotation=90)  # Rotate x-axis labels for readability

# Annotate the bars with their accuracy and MSE values at the top (centered)
for i, (acc, mse) in enumerate(zip(accuracies, mse_values)):
    plt.text(index[i] + bar_width/2, acc + 2, f'{acc}%', ha='center', va='bottom', fontsize=9)
    plt.text(index[i] + bar_width/2, mse + 2, f'{mse}%', ha='center', va='bottom', fontsize=9)

# Move the legend outside the graph area
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('accuracy_mse_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1) .csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['Accuracy - V'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Add MSE values
mse_values = df['RMSE - V']*100  # Assuming the column name is 'MSE - V'
mse_values = mse_values.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(0, 100)  # Adjust the limits as needed

# Create bars for accuracy and MSE
bar_width = 0.3
index = np.arange(len(dnn_configurations))
plt.bar(index, accuracies, bar_width, label='Accuracy', color='skyblue', align='center')
plt.bar(index + bar_width, mse_values, bar_width, label='MSE', color='lightcoral', alpha=0.7, align='center')

plt.xlabel('DNN Configuration')
plt.ylabel('Values')
plt.title('Accuracy and MSE for Different DNN Configurations for Valence')
plt.xticks(index + bar_width/2, dnn_configurations, rotation=90)  # Rotate x-axis labels for readability

# Annotate the bars with their accuracy and MSE values at the center of the bars
for i, (acc, mse) in enumerate(zip(accuracies, mse_values)):
    plt.text(index[i], acc + 2, f'{acc}%', ha='center', va='bottom', fontsize=9)
    plt.text(index[i] + bar_width, mse + 2, f'{mse}%', ha='center', va='bottom', fontsize=9)

# Move the legend outside the graph area
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('accuracy_mse_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1) .csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['Accuracy - V'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Add RMSE and Recall - V values
rmse_values = df['RMSE - V'] * 100  # Assuming the column name is 'RMSE - V'
recall_values = df['R2 Score - V'] * 100  # Assuming the column name is 'Recall - V'
rmse_values = rmse_values.round(2)  # Round to two decimal places
recall_values = recall_values.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(12, 6))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(0, 90)  # Adjust the limits as needed

# Create bars for accuracy, RMSE, and Recall - V
bar_width = 0.28
index = np.arange(len(dnn_configurations))
plt.bar(index, accuracies, bar_width, label='Accuracy -V', color='blue', align='center')
plt.bar(index + bar_width, rmse_values, bar_width, label='RMSE-V', color='red', alpha=0.7, align='center')
plt.bar(index + 2 * bar_width, recall_values, bar_width, label='R2 Score - V', color='green', alpha=0.7, align='center')

plt.xlabel('DNN Configuration')
plt.ylabel('Values')
plt.title('Performance Metrics for Different DNN Configurations for Valence')
plt.xticks(index + bar_width, dnn_configurations, rotation=90)  # Rotate x-axis labels for readability

# Annotate the bars with their values at the center of the bars
for i, (acc, rmse, recall) in enumerate(zip(accuracies, rmse_values, recall_values)):
    plt.text(index[i], acc + 2, f'{acc}%', ha='center', va='bottom', fontsize=9)
    plt.text(index[i] + bar_width, rmse + 2, f'{rmse}%', ha='center', va='bottom', fontsize=9)
    plt.text(index[i] + 2 * bar_width, recall + 2, f'{recall}%', ha='center', va='bottom', fontsize=9)

# Move the legend outside the graph area
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('metrics_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
