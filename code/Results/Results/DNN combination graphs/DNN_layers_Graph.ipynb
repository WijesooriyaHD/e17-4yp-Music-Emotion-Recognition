# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the Excel file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1).csv'
df = pd.read_csv(results_file)

# Extract DNN configurations and accuracies
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['Accuracy - A'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(dnn_configurations, accuracies, color='skyblue')
plt.xlabel('DNN Configuration')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy for Different DNN Configurations')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('accuracy_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1).csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['Accuracy - A'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(6, 10))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(80, 86)  # Adjust the limits as needed

plt.bar(dnn_configurations, accuracies, color='skyblue')
plt.xlabel('DNN Configuration')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy for Different DNN Configurations')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('accuracy_plot.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1).csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['Accuracy - A'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(6, 7))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(80, 86)  # Adjust the limits as needed

bars = plt.bar(dnn_configurations, accuracies, color='skyblue')
plt.xlabel('DNN Configuration')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy for Different DNN Configurations')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability

# Annotate the bars with their accuracy values at the top
for bar, acc in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2, acc + 0.1, f'{acc}%', ha='center', va='bottom', fontsize=9)

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('accuracy_plot.png')
# Out:
# WARNING:matplotlib.text:posx and posy should be finite values
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:matplotlib.text:posx and posy should be finite values

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file
from google.colab import drive
drive.mount('/content/drive')

# Define the path to the directory containing the feature files
directory_path = '/content/drive/MyDrive/FYP_dataset/features'
results_file = '/content/drive/MyDrive/FYP_dataset/Different_DNN_combinations/results_dnn_differnt_layers - Sheet1(1).csv'
df = pd.read_csv(results_file)

# Convert DNN configurations to strings
dnn_configurations = df['layres and units'].astype(str)
accuracies = df['Accuracy - V'] * 100  # Convert to percentages
accuracies = accuracies.round(2)  # Round to two decimal places

# Create a bar plot
plt.figure(figsize=(6, 7))  # Adjust the figure size as needed

# Set a custom y-axis range to visually see the differences
plt.ylim(75, 80)  # Adjust the limits as needed

bars = plt.bar(dnn_configurations, accuracies, color='blue')
plt.xlabel('DNN Configuration')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy for Different DNN Configurations')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability

# Annotate the bars with their accuracy values at the top
for bar, acc in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2, acc + 0.1, f'{acc}%', ha='center', va='bottom', fontsize=9)

# Display the plot or save it to a file
plt.tight_layout()
plt.show()  # To display the plot in your Jupyter Notebook or script
# To save the plot as an image file, you can use plt.savefig('accuracy_plot.png')
# Out:
# WARNING:matplotlib.text:posx and posy should be finite values
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:matplotlib.text:posx and posy should be finite values
